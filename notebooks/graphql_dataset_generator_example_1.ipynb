# %%
# !pip install gitpython
# %mkdir /content/data_collection
# %cd /content/data_collection
# !git clone https://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@github.com/Logende/GraphQLQueryNameConsistency.git
# %cd GraphQLQueryNameConsistency/dataset_generator
# !python3 dataset_generator/generator_toolchain.py 200 299
# Out:
# Collecting gitpython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 15.1 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.9 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.10 gitpython-3.1.31 smmap-5.0.0
# /content/data_collection
# Cloning into 'GraphQLQueryNameConsistency'...
# remote: Enumerating objects: 324, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 324 (delta 4), reused 8 (delta 3), pack-reused 314
# Receiving objects: 100% (324/324), 410.46 KiB | 16.42 MiB/s, done.
# Resolving deltas: 100% (215/215), done.
# /content/data_collection/GraphQLQueryNameConsistency/dataset_generator
# Start generator toolchain with repo 200 to 299.
# Create subset of dependents file: /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_dependents_200_299/dependents_apollo-client.csv
# Clone repos
# Begin endless cloning process.
# Attempt cloning of Github Repos.
# Start cloning Repo imodeljs/frontend-sample-showcase.
# Start cloning Repo anirudhvs/pragyan-ctf-22.
# Start cloning Repo broxus/ton-dex.
# Start cloning Repo ictsc/ictsc-score-server.
# Start cloning Repo yinMrsir/typescript-admin.
# Start cloning Repo CityOfBoston/digital.
# Start cloning Repo hyd628/delegation-dao-demo.
# Start cloning Repo brave/ads-ui.
# Start cloning Repo Popcorn-moe/Web.
# Start cloning Repo SwissLife-OSS/IdOps.
# Start cloning Repo councilofelders/numerbay.
# Start cloning Repo agiledev0115/meteor-boilerplate.
# Start cloning Repo renproject/command-center.
# Start cloning Repo orbiting/publikator-frontend.
# Start cloning Repo thomaswangio/react-producthunt.
# Start cloning Repo wani-hackase/wanictf21spring-writeup.
# Start cloning Repo libero/reviewer-submission.
# Start cloning Repo aerogear/graphql-testx.
# Start cloning Repo SwissLife-OSS/Boost.
# Start cloning Repo TopSpeed1017/spiritswap-frontend.
# Start cloning Repo BestCryptoKnight/react-admin-with-material-ui-next.
# Start cloning Repo atomist/sdm-pack-aspect.
# Start cloning Repo skovy/graphql-blog-client.
# Start cloning Repo terryyyz/CodeBaseFrontendReactjs.
# Start cloning Repo feedadoc/feedadoc.
# Start cloning Repo aws-samples/aws-appsync-presence-api.
# Start cloning Repo hashicorp/learn-terraform-preview-environment.
# Start cloning Repo Yash621/meta-meet.
# Start cloning Repo naji0329/test-nft-project.
# Start cloning Repo department-stockholm/apollo-component.
# Start cloning Repo bloxapp/awesome-ssv.
# Start cloning Repo HappyDream0317/impermax-x-uniswap-v2-interface.
# Start cloning Repo HappyDream0317/Microservices-GrowLabs.
# Start cloning Repo HappyDream0317/self-serve-mint.
# Start cloning Repo reservoirprotocol/seaport-oracle.
# Start cloning Repo Laravel-VPN-Admin/api-core.
# Start cloning Repo karimould/minimal-multi-language-gatsby-starter-netlify-cms.
# Start cloning Repo getflywheel/local-addon-notes.
# Start cloning Repo getflywheel/local-addon-image-optimizer.
# Start cloning Repo deliteser112/idie-device-rolls.
# Start cloning Repo imodeljs/itwin-viewer.
# Start cloning Repo dong-dohai/serverless-content-encoding.
# Start cloning Repo thestuntcoder/europratsya.
# Start cloning Repo mgx5kw/MistyDAO.
# Start cloning Repo dm-drogeriemarkt/lisa.
# Start cloning Repo danielwii/asuna-admin.
# Start cloning Repo chainsauce-org/chainsauce.
# Start cloning Repo DoBestMan/Bondswap-backend.
# Start cloning Repo RyanCCollins/ryancollinsio.
# Start cloning Repo Akord-com/akord-js.
# Start cloning Repo nguyentung9820/DEX.
# Start cloning Repo Meeovi/Collaborrate.
# Start cloning Repo stevenpslade/maas.
# Start cloning Repo deliteser112/meteor-boiler-plate-app.
# Start cloning Repo ssteiger/minimal-dao.
# Start cloning Repo 0xTranqui/lostandfound-zora-marketplace.
# Start cloning Repo bhargavaparoksham/scaffold-eth-lens-starter-kit.
# Start cloning Repo bcgov/digital.gov.bc.ca.
# Start cloning Repo yamapyblack/CryptoFrontier.
# Start cloning Repo alibaba-archive/serverless.
# Start cloning Repo kyma-incubator/varkes.
# Start cloning Repo samarjaffal/wuptick-frontend.
# Start cloning Repo Vandivier/devfit.
# Start cloning Repo DoBestMan/PrepDD.
# Start cloning Repo h-REA/holo-rea-proto.
# Start cloning Repo getflywheel/local-addon-boilerplate.
# Start cloning Repo malgamves/GameOfCharts.
# Start cloning Repo bgoonz/React_Notes_V3.
# Start cloning Repo Jckhe/playBoards-ts.
# Start cloning Repo setsun/react-koa-universal.
# Start cloning Repo cid-harvard/growth-lab-app-front-end.
# Start cloning Repo parity-asia/hackathon-2022-summer.
# Start cloning Repo shafayeatsumit/rugged-multisig.
# Start cloning Repo ruleslabs/interface.
# Start cloning Repo oumoussa98/leeters.
# Start cloning Repo impactasaurus/app.
# Start cloning Repo ziggy6792/cdk-monorepo-example-backend.
# Start cloning Repo newsguildny/nytimesguild.org.
# Start cloning Repo sumit-mahajan/generative-nft-interface.
# Start cloning Repo wslyvh/buidl-explorer.
# Start cloning Repo tomrutgers/middleman-webpack-netlify-cms.
# Start cloning Repo impactMarket/mobile-app.
# Start cloning Repo DoBestMan/spectrum.
# Start cloning Repo sazzer/pusher-mud.
# Start cloning Repo Open-NC/reentry-resources-hub.
# Start cloning Repo aws-samples/realtime-slot-car-racing-with-aws-amplify-aws-iot-core-and-amazon-kinesis-video-streams.
# Start cloning Repo aaronksaunders/amplify-remix-todos-1.
# Start cloning Repo wednesday-solutions/react-graphql-ts-template.
# Start cloning Repo collinsmuriuki/covid-19-monitor.
# Start cloning Repo DeltaPrimeLabs/deltaprime-primeloans.
# Start cloning Repo heyrict/cindy-realtime.
# Start cloning Repo tylim88/Create-Prisma-App.
# Start cloning Repo zapkub/cu-vivid-museum-wiki.
# Start cloning Repo Shopify/fulfillment-order-sample-app.
# Start cloning Repo treejer/web.
# Start cloning Repo SkyCaptainess/Shopify-nextjs.
# Start cloning Repo mrdulin/react-apollo-graphql-starter-kit.
# Start cloning Repo crewnew-git/sveltekit-hasura-docker.
# Start cloning Repo Russell1130/decentral-staking.
# Start cloning Repo mwhorse46/uoona.
# Went through all requested repos!
# Extract queries
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299 does not exist yet. Creating it.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/danielwii_asuna-admin
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/danielwii_asuna-admin having 159 candidate files.
# Found 10 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#         ${queryString}
#       `'.
# Unable to extract operation type from GQL section 'gql`
#           {
#             sys_model_schemas {
#               name
#               schema
#             }
#           }
#         `'.
# Unable to extract operation type from GQL section 'gql`
#           {
#             kvs(collection: "system.server") {
#               key
#               name
#               type
#               value
#             }
#           }
#         `'.
# Unable to extract operation type from GQL section 'gql`
#           {
#             __schema {
#               queryType {
#                 fields {
#                   name
#                 }
#               }
#             }
#           }
#         `'.
# Unable to extract operation type from GQL section 'gql`
#       {
#         kv(collection: "${collection}", key: "${key}") {
#           collection
#           key
#           updatedAt
#           name
#           value
#         }
#       }
#     `'.
# Unable to extract operation type from GQL section 'gql`
#         {
#           wechat: kv(collection: "system.wechat", key: "config") {
#             key
#             name
#             type
#             value
#           }
#           site: kv(collection: "app.settings", key: "site") {
#             key
#             name
#             type
#             value
#           }
#         }
#       `'.
# Unable to extract operation type from GQL section 'gql`
#       {
#         kv(collection: "${collection}", key: "${key}") {
#           collection
#           key
#           updatedAt
#           name
#           value
#         }
#       }
#     `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/malgamves_GameOfCharts
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/malgamves_GameOfCharts having 5 candidate files.
# Found 4 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/newsguildny_nytimesguild.org
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/newsguildny_nytimesguild.org having 71 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/aws-samples_aws-appsync-presence-api
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/aws-samples_aws-appsync-presence-api having 23 candidate files.
# Found 11 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/stevenpslade_maas
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/stevenpslade_maas having 76 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/shafayeatsumit_rugged-multisig
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/shafayeatsumit_rugged-multisig having 84 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/cid-harvard_growth-lab-app-front-end
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/cid-harvard_growth-lab-app-front-end having 135 candidate files.
# Found 8 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/hashicorp_learn-terraform-preview-environment
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/hashicorp_learn-terraform-preview-environment having 23 candidate files.
# Found 11 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/impactasaurus_app
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/impactasaurus_app having 281 candidate files.
# Found 84 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/imodeljs_frontend-sample-showcase
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/imodeljs_frontend-sample-showcase having 355 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/renproject_command-center
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/renproject_command-center having 159 candidate files.
# Found 3 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/DoBestMan_spectrum
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/DoBestMan_spectrum having 1734 candidate files.
# Found 192 gql strings in the repository.
# Found 3 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/SkyCaptainess_Shopify-nextjs
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/SkyCaptainess_Shopify-nextjs having 202 candidate files.
# Found 15 gql strings in the repository.
# Found 3 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/0xTranqui_lostandfound-zora-marketplace
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/0xTranqui_lostandfound-zora-marketplace having 65 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/TopSpeed1017_spiritswap-frontend
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/TopSpeed1017_spiritswap-frontend having 75 candidate files.
# Found 23 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   ${PairFields}
#   query pairs($allPairs: [Bytes]!) {
#     pairs(first: 500, where: { id_in: $allPairs }, orderBy: trackedReserveETH, orderDirection: desc) {
#       ...PairFields
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${TokenFields}
#   query tokens($tokenAddresses: [Bytes]!) {
#     pairs(where: { id_in: $tokenAddresses }) {
#       ...TokenFields
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${TokenFields}
#   query tokens {
#     tokens(first: 200, orderBy: tradeVolumeUSD, orderDirection: desc) {
#       ...TokenFields
#     }
#   }
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/getflywheel_local-addon-notes
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/getflywheel_local-addon-notes having 4 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/skovy_graphql-blog-client
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/skovy_graphql-blog-client having 56 candidate files.
# Found 10 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/councilofelders_numerbay
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/councilofelders_numerbay having 151 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/wani-hackase_wanictf21spring-writeup
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/wani-hackase_wanictf21spring-writeup having 8 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/HappyDream0317_self-serve-mint
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/HappyDream0317_self-serve-mint having 66 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/sumit-mahajan_generative-nft-interface
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/sumit-mahajan_generative-nft-interface having 23 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/crewnew-git_sveltekit-hasura-docker
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/crewnew-git_sveltekit-hasura-docker having 30 candidate files.
# Found 7 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/aerogear_graphql-testx
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/aerogear_graphql-testx having 24 candidate files.
# Found 3 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#     ${schema}
#   `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/mwhorse46_uoona
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/mwhorse46_uoona having 58 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/bhargavaparoksham_scaffold-eth-lens-starter-kit
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/bhargavaparoksham_scaffold-eth-lens-starter-kit having 65 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/nguyentung9820_DEX
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/nguyentung9820_DEX having 15 candidate files.
# Found 4 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/orbiting_publikator-frontend
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/orbiting_publikator-frontend having 235 candidate files.
# Found 49 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#     ${TeaserEmbedComment.data.query}
#   `'.
# Unable to extract operation type from GQL section 'gql`
#     ${TeaserActiveDebates.data.query}
#   `'.
# Unable to extract operation type from GQL section 'gql`
#     ${TeaserMyMagazine.data.query}
#   `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/SwissLife-OSS_IdOps
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/SwissLife-OSS_IdOps having 29 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/feedadoc_feedadoc
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/feedadoc_feedadoc having 93 candidate files.
# Found 7 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/DoBestMan_Bondswap-backend
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/DoBestMan_Bondswap-backend having 100 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/thomaswangio_react-producthunt
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/thomaswangio_react-producthunt having 8 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#       {
#         user(username: ${username}) {
#           id
#           username
#           url
#           name
#           profileImage(size: 200)
#           isMaker
#           madePosts {
#             totalCount
#           }
#           submittedPosts {
#             totalCount
#           }
#         }
#       }
#     `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/CityOfBoston_digital
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/CityOfBoston_digital having 615 candidate files.
# Found 23 gql strings in the repository.
# Found 7 constants in the repository.
# Unable to extract operation type from GQL section 'gql`{
#         commissions(query:
#             "${this.props.submittedKeywords}",
#             policyTypeIds: ${submittedItems},
#             hasOpenSeats: ${
#               this.props.submittedSeats === 'seats-open' ? true : null
#             }
#         ) {
#             id
#             name
#             policyType {
#                 name
#             }
#             homepageUrl
#         }
#     }`'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     policyTypes {
#       id
#       name
#     }
#   }
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/agiledev0115_meteor-boilerplate
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/agiledev0115_meteor-boilerplate having 301 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#     ${UserTypes}
#     ${DocumentTypes}
#     ${CommentTypes}
#     ${UserSettingsTypes}
#
#     type Query {
#       documents: [Document]
#       document(_id: String): Document
#       user(_id: String): User
#       users(currentPage: Int, perPage: Int, search: String): Users
#       userSettings: [UserSetting]
#       exportUserData: UserDataExport
#       oAuthServices(services: [String]): [String]
#     }
#
#     type Mutation {
#       addDocument(title: String, body: String, cover: CoverInput, isPublic: Boolean): Document
#       updateDocument(_id: String!, title: String, body: String, cover: CoverInput, isPublic: Boolean): Document
#       removeDocument(_id: String!): Document
#       addComment(documentId: String!, comment: String!): Comment
#       removeComment(commentId: String!): Comment
#       updateUser(user: UserInput): User
#       removeUser(_id: String): User
#       addUserSetting(setting: UserSettingInput): UserSetting
#       updateUserSetting(setting: UserSettingInput): UserSetting
#       removeUserSetting(_id: String!): UserSetting
#       sendVerificationEmail: User
#       sendWelcomeEmail: User
#     }
#
#     type Subscription {
#       commentAdded(documentId: String!): Comment
#     }
#   `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Russell1130_decentral-staking
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Russell1130_decentral-staking having 55 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/samarjaffal_wuptick-frontend
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/samarjaffal_wuptick-frontend having 454 candidate files.
# Found 62 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#     {
#         testUser
#     }
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/DoBestMan_PrepDD
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/DoBestMan_PrepDD having 246 candidate files.
# Found 36 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/SwissLife-OSS_Boost
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/SwissLife-OSS_Boost having 33 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/ssteiger_minimal-dao
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/ssteiger_minimal-dao having 72 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Laravel-VPN-Admin_api-core
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Laravel-VPN-Admin_api-core having 7 candidate files.
# Found 11 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/BestCryptoKnight_react-admin-with-material-ui-next
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/BestCryptoKnight_react-admin-with-material-ui-next having 88 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/heyrict_cindy-realtime
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/heyrict_cindy-realtime having 516 candidate files.
# Found 75 gql strings in the repository.
# Found 1 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/tomrutgers_middleman-webpack-netlify-cms
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/tomrutgers_middleman-webpack-netlify-cms having 5 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/parity-asia_hackathon-2022-summer
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/parity-asia_hackathon-2022-summer having 1324 candidate files.
# Found 21 gql strings in the repository.
# Found 4 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#       {
#         pool(id: "${params.address}") {
#           id
#           active
#           cap
#           controller
#           finalized
#           crp
#           swapFee
#           totalWeight
#           totalSwapVolume
#           totalSwapFee
#           createTime
#           joinsCount
#           exitsCount
#           liquidity
#           tokensList
#           swapsCount
#           holdersCount
#           tx
#           rights
#           controller
#           crpController
#           cap
#           createTime
#           name
#           symbol
#           tokens(orderBy: "denormWeight", orderDirection: "desc") {
#             id
#             address
#             balance
#             decimals
#             symbol
#             denormWeight
#           }
#           swaps(
#             first: 1
#             orderBy: "timestamp"
#             orderDirection: "desc"
#             where: { timestamp_lt: 1655011996 }
#           ) {
#             poolTotalSwapVolume
#           }
#         }
#       }
#     `'.
# Unable to extract operation type from GQL section 'gql`
#       {
#         swaps(
#           where: { poolAddress: "${params.address}" }
#           first: 20
#           skip: 0
#           orderBy: "timestamp"
#           orderDirection: "desc"
#         ) {
#           id
#           tokenIn
#           tokenInSym
#           tokenAmountIn
#           tokenOut
#           tokenOutSym
#           tokenAmountOut
#           poolTotalSwapVolume
#           timestamp
#           value
#           feeValue
#         }
#       }
#     `'.
# Unable to extract operation type from GQL section 'gql`
#       {
#         pools(
#           where: {
#             active: true
#             tokensCount_gt: 1
#             crpController: "0x4Fd1A47106A2c18DE14941e99648762ed32A875d"
#             tokensList_not: []
#           }
#           first: 20
#           skip: 0
#           orderBy: "liquidity"
#           orderDirection: "desc"
#         ) {
#           id
#           publicSwap
#           finalized
#           crp
#           rights
#           swapFee
#           totalWeight
#           totalShares
#           totalSwapVolume
#           liquidity
#           tokensList
#           swapsCount
#           tokens(orderBy: "denormWeight", orderDirection: "desc") {
#             id
#             address
#             balance
#             decimals
#             symbol
#             denormWeight
#           }
#           swaps(
#             first: 1
#             orderBy: "timestamp"
#             orderDirection: "desc"
#             where: { timestamp_lt: 1654758000 }
#           ) {
#             poolTotalSwapVolume
#           }
#         }
#       }
#     `'.
# Unable to extract operation type from GQL section 'gql`
#       {
#         pools(
#           where: {
#             active: true
#             tokensCount_gt: 1
#             crp: true
#             tokensList_not: []
#           }
#           first: 20
#           skip: 0
#           orderBy: "liquidity"
#           orderDirection: "desc"
#         ) {
#           id
#           publicSwap
#           finalized
#           crp
#           rights
#           swapFee
#           totalWeight
#           totalShares
#           totalSwapVolume
#           liquidity
#           tokensList
#           swapsCount
#           tokens(orderBy: "denormWeight", orderDirection: "desc") {
#             id
#             address
#             balance
#             decimals
#             symbol
#             denormWeight
#           }
#           swaps(
#             first: 1
#             orderBy: "timestamp"
#             orderDirection: "desc"
#             where: { timestamp_lt: 1655010000 }
#           ) {
#             poolTotalSwapVolume
#           }
#         }
#       }
#     `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/DeltaPrimeLabs_deltaprime-primeloans
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/DeltaPrimeLabs_deltaprime-primeloans having 150 candidate files.
# Found 0 gql strings in the repository.
# Found 2 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/wslyvh_buidl-explorer
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/wslyvh_buidl-explorer having 31 candidate files.
# Found 2 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/broxus_ton-dex
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/broxus_ton-dex having 48 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/karimould_minimal-multi-language-gatsby-starter-netlify-cms
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/karimould_minimal-multi-language-gatsby-starter-netlify-cms having 13 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/getflywheel_local-addon-image-optimizer
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/getflywheel_local-addon-image-optimizer having 51 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/reservoirprotocol_seaport-oracle
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/reservoirprotocol_seaport-oracle having 155 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/atomist_sdm-pack-aspect
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/atomist_sdm-pack-aspect having 120 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/anirudhvs_pragyan-ctf-22
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/anirudhvs_pragyan-ctf-22 having 12 candidate files.
# Found 3 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Yash621_meta-meet
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Yash621_meta-meet having 38 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/collinsmuriuki_covid-19-monitor
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/collinsmuriuki_covid-19-monitor having 49 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/oumoussa98_leeters
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/oumoussa98_leeters having 3 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/bloxapp_awesome-ssv
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/bloxapp_awesome-ssv having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/thestuntcoder_europratsya
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/thestuntcoder_europratsya having 52 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/yamapyblack_CryptoFrontier
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/yamapyblack_CryptoFrontier having 65 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Popcorn-moe_Web
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Popcorn-moe_Web having 38 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
# 				{
# 					me {
# 						id
# 					}
# 				}
# 			`'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Open-NC_reentry-resources-hub
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Open-NC_reentry-resources-hub having 6 candidate files.
# Found 3 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/mrdulin_react-apollo-graphql-starter-kit
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/mrdulin_react-apollo-graphql-starter-kit having 470 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/chainsauce-org_chainsauce
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/chainsauce-org_chainsauce having 6 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/aws-samples_realtime-slot-car-racing-with-aws-amplify-aws-iot-core-and-amazon-kinesis-video-streams
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/aws-samples_realtime-slot-car-racing-with-aws-amplify-aws-iot-core-and-amazon-kinesis-video-streams having 37 candidate files.
# Found 12 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/treejer_web
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/treejer_web having 37 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Shopify_fulfillment-order-sample-app
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Shopify_fulfillment-order-sample-app having 17 candidate files.
# Found 2 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     shop {
#       fulfillmentOrders(first: 10) {
#         edges {
#           node {
#             id
#             order {
#               legacyResourceId
#             }
#             assignedLocation {
#               name
#             }
#           }
#         }
#       }
#     }
#   }
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/deliteser112_meteor-boiler-plate-app
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/deliteser112_meteor-boiler-plate-app having 170 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#     ${UserTypes}
#     ${DocumentTypes}
#     ${CommentTypes}
#     ${UserSettingsTypes}
#
#     type Query {
#       documents: [Document]
#       document(_id: String): Document
#       user(_id: String): User
#       users(currentPage: Int, perPage: Int, search: String): Users
#       userSettings: [UserSetting]
#       exportUserData: UserDataExport
#       oAuthServices(services: [String]): [String]
#     }
#
#     type Mutation {
#       addDocument(title: String, body: String): Document
#       updateDocument(_id: String!, title: String, body: String, isPublic: Boolean): Document
#       removeDocument(_id: String!): Document
#       addComment(documentId: String!, comment: String!): Comment
#       removeComment(commentId: String!): Comment
#       updateUser(user: UserInput): User
#       removeUser(_id: String): User
#       addUserSetting(setting: UserSettingInput): UserSetting
#       updateUserSetting(setting: UserSettingInput): UserSetting
#       removeUserSetting(_id: String!): UserSetting
#       sendVerificationEmail: User
#       sendWelcomeEmail: User
#     }
#
#     type Subscription {
#       commentAdded(documentId: String!): Comment
#     }
#   `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Akord-com_akord-js
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/Akord-com_akord-js having 65 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/HappyDream0317_impermax-x-uniswap-v2-interface
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_200_299/HappyDream0317_impermax-x-uniswap-v2-interface having 246 candidate files.
# Found 14 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`{
#     lendingPool(id: "${lowerCasedUniswapV2PairAddress}") {
#       id
#       borrowable0 ${borrowableStr}
#       borrowable1 ${borrowableStr}
#       collateral {
#         id
#         totalBalance
#         totalBalanceUSD
#         safetyMargin
#         liquidationIncentive
#         exchangeRate
#       }
#       pair {
#         reserve0
#         reserve1
#         reserveUSD
#         token0Price
#         token1Price
#         derivedUSD
#       }
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     blocks (first: 1, orderBy: timestamp, orderDirection: desc, where: { timestamp_gt: ${timestamp}, timestamp_lt: ${timestamp + 600} }) {
#       number
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     pairs ( block: {number: ${blockNumber}} where: { id_in: [${addressString}]} ) {
#       id
#       volumeUSD
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     pairs ( where: { id_in: [${addressString}]} ) {
#       id
#       reserveUSD
#       volumeUSD
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#   ximxes(first: 1) {
#     totalSupply
#     totalBalance
#     exchangeRate
#     dailyAPR
#   }
# }`'.
# Unable to extract operation type from GQL section 'gql`{
#   reservesDistributors(first:1) {
#     balance
#     periodLength
#     lastClaim
#     distributed
#   }
# }`'.
# Unable to extract operation type from GQL section 'gql`{
#   lendingPools(first: 1000, orderBy: totalBorrowsUSD, orderDirection: desc) {
#     id
#     borrowable0 ${borrowableStr}
#     borrowable1 ${borrowableStr}
#     collateral {
#       id
#       totalBalance
#       totalBalanceUSD
#       safetyMargin
#       liquidationIncentive
#       exchangeRate
#     }
#     pair {
#       reserve0
#       reserve1
#       reserveUSD
#       token0Price
#       token1Price
#       derivedUSD
#     }
#   }
# }`'.
# Unable to extract operation type from GQL section 'gql`{
#   impermaxFactories(first: 1) {
#     totalBalanceUSD
#     totalSupplyUSD
#     totalBorrowsUSD
#   }
# }`'.
# Unable to extract operation type from GQL section 'gql`{
#     user(id: "${account.toLowerCase()}") {
#       ximxBalance
#       lastExchangeRate
#       totalEarned
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     lendingPools(first: 1000, orderBy: totalBorrowsUSD, orderDirection: desc) {
#       id
#       borrowable0 ${borrowableStr}
#       borrowable1 ${borrowableStr}
#       collateral {
#         id
#         totalBalance
#         totalBalanceUSD
#         safetyMargin
#         liquidationIncentive
#         exchangeRate
#       }
#       pair {
#         reserve0
#         reserve1
#         reserveUSD
#         token0Price
#         token1Price
#         derivedUSD
#       }
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     blocks (first: 1, orderBy: timestamp, orderDirection: desc, where: { timestamp_gt: ${timestamp}, timestamp_lt: ${timestamp + 600} }) {
#       number
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     pairs ( block: {number: ${blockNumber}} where: { id_in: [${addressString}]} ) {
#       id
#       volumeUSD
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     pairs ( where: { id_in: [${addressString}]} ) {
#       id
#       reserveUSD
#       volumeUSD
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     user(id: "${account.toLowerCase()}") {
#       collateralPositions(first:1000) {
#         balance
#         collateral {
#           lendingPool {
#             id
#           }
#         }
#       }
#       supplyPositions(first:1000) {
#         balance
#         borrowable {
#           underlying {
#             id
#           }
#           lendingPool {
#             id
#           }
#         }
#       }
#       borrowPositions(first:1000) {
#         borrowBalance
#         borrowIndex
#         borrowable {
#           underlying {
#             id
#           }
#           lendingPool {
#             id
#           }
#         }
#       }
#     }
#   }`'.
# ...
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/setsun_react-koa-universal.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/danielwii_asuna-admin.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/crewnew-git_sveltekit-hasura-docker.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/hashicorp_learn-terraform-preview-environment.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/wslyvh_buidl-explorer.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/councilofelders_numerbay.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/malgamves_GameOfCharts.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/deliteser112_meteor-boiler-plate-app.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/anirudhvs_pragyan-ctf-22.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/TopSpeed1017_spiritswap-frontend.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/parity-asia_hackathon-2022-summer.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/aaronksaunders_amplify-remix-todos-1.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/heyrict_cindy-realtime.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/karimould_minimal-multi-language-gatsby-starter-netlify-cms.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/Jckhe_playBoards-ts.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/orbiting_publikator-frontend.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/HappyDream0317_impermax-x-uniswap-v2-interface.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/getflywheel_local-addon-image-optimizer.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/ziggy6792_cdk-monorepo-example-backend.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/Yash621_meta-meet.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/bcgov_digital.gov.bc.ca.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/thomaswangio_react-producthunt.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/Vandivier_devfit.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/collinsmuriuki_covid-19-monitor.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/impactasaurus_app.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/Popcorn-moe_Web.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/DoBestMan_Bondswap-backend.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/mgx5kw_MistyDAO.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/zapkub_cu-vivid-museum-wiki.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/newsguildny_nytimesguild.org.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/HappyDream0317_self-serve-mint.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/SkyCaptainess_Shopify-nextjs.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/aws-samples_realtime-slot-car-racing-with-aws-amplify-aws-iot-core-and-amazon-kinesis-video-streams.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/CityOfBoston_digital.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/imodeljs_frontend-sample-showcase.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/broxus_ton-dex.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/Akord-com_akord-js.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/getflywheel_local-addon-notes.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/feedadoc_feedadoc.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/department-stockholm_apollo-component.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/thestuntcoder_europratsya.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/wednesday-solutions_react-graphql-ts-template.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/DoBestMan_spectrum.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/shafayeatsumit_rugged-multisig.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/sazzer_pusher-mud.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/aws-samples_aws-appsync-presence-api.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/getflywheel_local-addon-boilerplate.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/stevenpslade_maas.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/ruleslabs_interface.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/agiledev0115_meteor-boilerplate.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/HappyDream0317_Microservices-GrowLabs.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/impactMarket_mobile-app.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_200_299/treejer_web.yaml
# Generate negative dataset
# Positive dataset:
# [{"type": "query", "name": "cliLoginById($id: String!)", "content": "{\n        cliLoginById(id: $id) {\n          encryptedAccessToken\n          encryptedIdToken\n          encryptedRefreshToken\n          encryptedKey\n          encryptedIv\n        }\n      }"}, {"type": "query", "name": "cliLoginById($id: String!)", "content": "{\n          cliLoginById(id: $id) {\n            encryptedAccessToken\n            encryptedIdToken\n            encryptedRefreshToken\n            encryptedKey\n            encryptedIv\n          }\n        }"}, {"type": "mutation", "name": "archiveService($name: String!)", "content": "{\n          archiveService(name: $name) {\n            archived\n          }\n        }"}, {"type": "mutation", "name": "publishService($service: ServicePublishInputType!)", "content": "{\n            publishService(service: $service) {\n              name\n            }\n          }"}, {"type": "query", "name": "UserLists", "content": "{\n    userLists {\n      id\n      lists {\n        id\n        name\n        sections {\n          id\n          name\n        }\n      }\n    }\n  }"}, {"type": "query", "name": "publicTaskMessages($taskId: ID!)", "content": "{\n    publicTaskMessages(taskId: $taskId) {\n      message\n      user {\n        fullName\n      }\n      createdAt\n    }\n  }"}, {"type": "query", "name": "UserForPasswordReset($token: String!)", "content": "{\n    userForPasswordReset(token: $token) {\n      email\n      resetPasswordPeriodValid\n    }\n  }"}, {"type": "query", "name": "AllRoles", "content": "{\n    roles {\n      id\n      name\n    }\n  }"}, {"type": "query", "name": "CurrentUser", "content": "{\n    currentUser {\n      id\n      user {\n        id\n        email\n        fullName\n        displayName\n        profileUrl\n        lastViewedCompanyId\n        ownedCompanies {\n          id\n          name\n        }\n        companies {\n          id\n          name\n          logoUrl\n        }\n        teams {\n          id\n          companyId\n          name\n        }\n        roles {\n          id\n          name\n          companyId\n        }\n      }\n    }\n  }"}, {"type": "query", "name": "privateTaskMessages($taskId: ID!)", "content": "{\n    privateTaskMessages(taskId: $taskId) {\n      message\n      user {\n        fullName\n      }\n      createdAt\n    }\n  }"}, {"type": "query", "name": "CompanyUsers($companyId: ID!, $teamId: ID, $limit: Int, $offset: Int)", "content": "{\n    companyUsers(\n      CompanyId: $companyId\n      TeamId: $teamId\n      limit: $limit\n      offset: $offset\n    ) {\n      company {\n        id\n        name\n        teams {\n          id\n          name\n        }\n      }\n      users {\n        id\n        fullName\n        profileUrl\n        roles {\n          id\n          name\n          companyId\n        }\n        teams {\n          id\n          name\n          companyId\n        }\n        companies {\n          id\n          name\n          logoUrl\n        }\n      }\n    }\n  }"}, {"type": "query", "name": "AllTemplates", "content": "{\n    templateLists {\n      id\n      name\n      tasks {\n        id\n        name\n        section {\n          id\n          name\n        }\n        description\n        priority\n        status\n      }\n    }\n  }"}, {"type": "query", "name": "CompanySettings($id: ID!)", "content": "{\n    company(id: $id) {\n      id\n      name\n      logoUrl\n      parents {\n        id\n        name\n        logoUrl\n      }\n      brokers {\n        id\n        name\n        logoUrl\n      }\n      totalUsers\n      totalStorage\n      subscription {\n        id\n        maxUsers\n        maxStorage\n      }\n      autoPdf\n      autoWatermark\n      previewOnly\n    }\n  }"}, {"type": "query", "name": "UserTasks(\n    $listIds: [ID!]!\n    $sectionIds: [ID!]!\n    $offset: Int\n    $limit: Int\n  )", "content": "{\n    userTasks(\n      listIds: $listIds\n      sectionIds: $sectionIds\n      offse ...
# Negative dataset:
# [{"type": "subscription", "name": "subscribeToNewMessages($thread: ID!)", "content": "{\n            updateGroup(id: $id, input: $input) {\n              id\n              name\n              object\n              created_at\n              updated_at\n              users {\n                id\n              }\n              users_count\n              servers {\n                id\n              }\n              servers_count\n            }\n          }"}, {"type": "query", "name": "Community($uid: String!)", "content": "{\n    community(id: $id) {\n      ...communityInfo\n      ...communityMetaData\n    }\n  }\n  ${communityInfoFragment}\n  ${communityMetaDataFragment}"}, {"type": "query", "name": "", "content": "{\n    allProducts {\n      id\n      name\n      price\n      description\n      photo {\n        id\n        image {\n          publicUrlTransformed\n        }\n      }\n    }\n  }"}, {"type": "query", "name": "($address: String, $userId: String!, $after: String)", "content": "{\n    application (id : $appId){\n      package (id : $packageId){\n        eventDefinition(id: $apiId) { \n          id \n          name \n          description\n          spec {\n            data format type \n          }\n        }\n      }\n    }\n  }"}, {"type": "mutation", "name": "signIn(\n    $email: String!\n    $context: String\n    $consents: [String!]\n    $tokenType: SignInTokenType\n  )", "content": "{\n    meta {\n      coreMetrics {\n        dau\n        wau\n        mau\n        dac\n        wac\n        mac\n        cpu\n        mpu\n        tpu\n        users\n        communities\n        threads\n        dmThreads\n        threadMessages\n        dmMessages\n        date\n      }\n      usersGrowth {\n        count\n        dau\n        wau\n        mau\n        weeklyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        monthlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        quarterlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n      }\n      communitiesGrowth {\n        count\n        weeklyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        monthlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        quarterlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n      }\n      channelsGrowth {\n        count\n        weeklyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        monthlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        quarterlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n      }\n      threadsGrowth {\n        count\n        weeklyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        monthlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        quarterlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n      }\n      directMessageThreadsGrowth {\n        count\n        weeklyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        monthlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        quarterlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n      }\n      threadMessagesGrowth {\n        count\n        weeklyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        monthlyGrowth {\n          growth\n          currentPeriodCount\n          prevPeriodCount\n        }\n        quarterlyGrowth {\n          growth\n          curre ...

# %%
# !python3 dataset_generator/generator_toolchain.py 500 599
# Out:
# Start generator toolchain with repo 500 to 599.
# Create subset of dependents file: /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_dependents_500_599/dependents_apollo-client.csv
# Clone repos
# Begin endless cloning process.
# Attempt cloning of Github Repos.
# Start cloning Repo Polygon-Academy/nftmarketexample.
# Start cloning Repo speckleworks/speckle-website.
# Start cloning Repo jackmorrison12/personal-site.
# Start cloning Repo sinkyoungdeok/docker.
# Start cloning Repo broxus/everscale-yield-farming.
# Start cloning Repo beepsoft/hasura-bliq.
# Start cloning Repo Popcorn-moe/Admin.
# Start cloning Repo MX56893/restaurant-food-delivery-v1.
# Start cloning Repo AllTwinkleStars/recat.
# Start cloning Repo JakobJK/framethrower.
# Start cloning Repo mjtechworks/daohaus-web.
# Start cloning Repo react-cosmos/react-cosmos-classic.
# Start cloning Repo kpyaoqi/chaincamp.
# Start cloning Repo hasura/sample-apps.
# Start cloning Repo thisdot/blog-demos.
# Start cloning Repo samuelkong/liferay-portal.
