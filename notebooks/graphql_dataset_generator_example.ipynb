# %%
# !pip install gitpython
# Out:
# Collecting gitpython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 5.3 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.7 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.10 gitpython-3.1.31 smmap-5.0.0

# %%
# %mkdir /content/data_collection
# %cd /content/data_collection
# Out:
# /content/data_collection

# %%
# !git clone https://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@github.com/Logende/GraphQLQueryNameConsistency.git
# %cd GraphQLQueryNameConsistency/dataset_generator
# Out:
# Cloning into 'GraphQLQueryNameConsistency'...
# remote: Enumerating objects: 319, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 319 (delta 0), reused 2 (delta 0), pack-reused 314
# Receiving objects: 100% (319/319), 410.10 KiB | 2.68 MiB/s, done.
# Resolving deltas: 100% (211/211), done.
# /content/data_collection/GraphQLQueryNameConsistency/GraphQLQueryNameConsistency/dataset_generator

# %%
# !python3 dataset_generator/generator_toolchain.py 0 99
# Out:
# Start generator toolchain with repo 0 to 99.
# Create subset of dependents file: /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_dependents_0_99/dependents_apollo-client.csv
# Clone repos
# Begin endless cloning process.
# Attempt cloning of Github Repos.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/withspectrum_spectrum already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nhost_nhost already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/ashutosh1919_masterPortfolio already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Canner_cannercms already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/datopian_portaljs already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/42atomys_stud42 already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/guidone_node-red-contrib-chatbot already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/replicatedhq_kots already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/SaraVieira_awesome-talks already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/saleor_saleor-storefront already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/aerogear_offix already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/aws-samples_lambda-refarch-imagerecognition already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/OriginProtocol_origin already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/AztecProtocol_aztec-v1 already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/eea-oasis_baseline already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/apollographql_reason-apollo already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/grand-stack_grand-stack-starter already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Shopify_shopify-demo-app-node-react already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/aragon_aragon-apps already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/manikandanraji_twitter-clone-frontend already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/functionless_functionless already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/stealthdrop_stealthdrop already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/apollographql_apollo-link-persisted-queries already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/FormidableLabs_seattlejsconf-app already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Shopify_product-reviews-sample-app already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/hiroppy_ssr-sample already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Epistimio_orion already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/stackrole_gatsby-starter-foundation already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/bandprotocol_bandchain already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/shoutem_extensions already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/adieuadieu_retinal already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Ninjas-Code-official_Enatega-Restaurant-Solution already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/hasura_json2graphql already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nhn_toast-ui.vue-calendar already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nervosnetwork_muta already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/awslabs_aws-dataall already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/tokopedia_treats already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/hasura_client-side-graphql already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Uniswap_org-v1 already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/alytrics_yaba-social already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/4GeeksAcademy_Templates-Boilerplates already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/delucis_astro-netlify-cms already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/SalesforceCommerceCloud_sfcc-sample-apps already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/katopz_react-apollo-graphql-github-example already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/grand-stack_graphql-auth-directives already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/LFSCamargo_Chatify already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/docker-hy_docker-hy.github.io already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/18F_handbook already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/0xHexE_keycloak-hasura-connector already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/gil--_gatsby-starter-shopify-app already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/gil--_gatsby-starter-shopifypwa already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/infrastructure-components_infrastructure-components already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/starknet-io_starknet-website already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/DidoMarchet_starter-kit-nuxt-locomotive-scroll already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/System-Glitch_Solidity-IDE already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Uniswap_api-deprecated already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/aws-samples_aws-builders-fair-projects already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/BuidlGuidl_abi.ninja already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/realm_realm-graphql already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/henry40408_awesome-stars already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/strues_boldr already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/lumen-cms_lumen-cms already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/denniske_aoe2companion already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Ninjas-Code-official_Marketplace-Food-Delivery-Solution already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Bayer-Group_ol-kit already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/monopayments_iban.im already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/strapi_strapi-starter-angular-blog already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/javamonn_sunspot already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/xilibi2003_training_camp_2 already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/kubernetes-hy_kubernetes-hy.github.io already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/m-rgba_hasura-django-starter already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/vgrafe_nextjs-auth0-hasura already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/hygraph_example_01_nextjs_apollo already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nerdify_db-schema-diagram already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/aws-amplify_amplify-category-api already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/SashenJayathilaka_Unique-Project-Ideas already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/briancaffey_django-postgres-vue-gitlab-ecs already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/gitcoinco_passport-sdk already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/IndexCoop_index-ui already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/arkhn_pyrog already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/rigelprotocol_SmartswapDappV2 already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nikgraf_graphql-apollo-client-course already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/aerogear_datasync-voyager already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/aws-amplify_amplify-codegen already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nhn_toast-ui.vue-chart already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/chaoss_grimoirelab-sortinghat already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/launchscout_graphql-admin-react already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/usecannon_cannon already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/graphile_bootstrap-react-apollo already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/dotansimha_graphql-code-generator-community already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/AISHU-Technology_kweaver already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/delegatable_MobyMask already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/keystonejs_keystone-jamstack-plus already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/coderplanets_coderplanets_admin already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/abhi40308_instagram-clone already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/kyma-project_console already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/simarmannsingh_gatsby-netlifycms-modern-blog already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/republik_plattform already exists. Not cloning again.
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/pangolindex_pangolin.exchange already exists. Not cloning again.
# Went through all requested repos!
# Extract queries
# Folder /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99 already exists.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/delegatable_MobyMask
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/delegatable_MobyMask having 108 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Shopify_product-reviews-sample-app
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Shopify_product-reviews-sample-app having 71 candidate files.
# Found 12 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Uniswap_api-deprecated
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Uniswap_api-deprecated having 23 candidate files.
# Found 10 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/abhi40308_instagram-clone
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/abhi40308_instagram-clone having 14 candidate files.
# Found 12 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     Post(order_by: { created_at: desc }) {
#       id
#     }
#   }
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/chaoss_grimoirelab-sortinghat
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/chaoss_grimoirelab-sortinghat having 59 candidate files.
# Found 44 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/aerogear_datasync-voyager
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/aerogear_datasync-voyager having 61 candidate files.
# Found 17 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#
#   # In the older version of graphql in the data sync server
#   # We did not have to define the directive here.
#   # For some reason we do now, otherwise makeExecutableSchema does not work.
#
#   type Query {
#     hello: String @hasRole(role: "admin")
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`{
#       hello
#     }`'.
# Unable to extract operation type from GQL section 'gql`{
#         fails
#       }`'.
# Unable to extract operation type from GQL section 'gql`{
#       getUser(id:0){id,name,favoriteHorse{name,breed}}
#     }`'.
# Unable to extract operation type from GQL section 'gql`{
#       getUser(id:1){
#         id,
#         name,
#         favoriteHorse{name,breed},
#         friends{
#           id,
#           name,
#           favoriteHorse{name,breed}
#         }}
#     }`'.
# Unable to extract operation type from GQL section 'gql`{
#         doesNotExist
#       }`'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/guidone_node-red-contrib-chatbot
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/guidone_node-red-contrib-chatbot having 454 candidate files.
# Found 70 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`${translatedQuery}`'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/BuidlGuidl_abi.ninja
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/BuidlGuidl_abi.ninja having 73 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/dotansimha_graphql-code-generator-community
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/dotansimha_graphql-code-generator-community having 289 candidate files.
# Found 238 gql strings in the repository.
# Found 12 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#             : null,
#         ),
#         addExplicitOverride: getConfigValue(rawConfig.addExplicitOverride, false),
#       },
#       documents,
#     );
#
#     if (this.config.importOperationTypesFrom) {
#       this._externalImportPrefix = `'.
# Unable to extract operation type from GQL section 'gql`\n');
#       // To make sure we don't have apollo v3 related code
#       expect(content.content).not.toContain('Apollo.');
#       expect(content.content).toContain('ApolloReactCommon.');
#       expect(content.content).toContain('ApolloReactHoc.');
#       expect(content.content).toContain('ApolloReactComponents.');
#       expect(content.content).toContain('ApolloReactHooks.');
#
#       await validateTypeScript(content, schema, docs, {});
#     });
#   });
#
#   describe('Issues', () => {
#     it.each([
#       {
#         document: `'.
# Unable to extract operation type from GQL section 'gql`);
#
#       await validateTypeScript(content, schema, docs, {});
#     });
#
#     it('should NOT generate inline fragment docs for external mode: file with operation NOT using inline fragment', async () => {
#       const docs = [
#         {
#           location: '',
#           document: parse(/* GraphQL */ `'.
# Unable to extract operation type from GQL section 'gql`);
#       await validateTypeScript(content, schema, docs, {});
#     });
#
#     it('should NOT generate inline fragment docs for external mode: file with just fragment', async () => {
#       const docs = [
#         {
#           location: '',
#           document: parse(/* GraphQL */ `'.
# Unable to extract operation type from GQL section 'gql`);
#
#       await validateTypeScript(content, schema, docs, { ...config });
#     });
#
#     it('should import Operations from one external file and use it in Query component', async () => {
#       const config: ReactApolloRawPluginConfig = {
#         documentMode: DocumentMode.external,
#         importDocumentNodeExternallyFrom: 'path/to/documents.tsx',
#         withComponent: true,
#         withHooks: false,
#         withHOC: false,
#       };
#
#       const docs = [{ location: '', document: basicDoc }];
#
#       const content = (await plugin(schema, docs, config, {
#         outputFile: 'graphql.tsx',
#       })) as Types.ComplexPluginOutput;
#
#       expect(content.prepend).toContain(`'.
# Unable to extract operation type from GQL section 'gql`,
#       ),
#       hooksSuffix: getConfigValue(rawConfig.hooksSuffix, ''),
#     });
#
#     this._externalImportPrefix = this.config.importOperationTypesFrom
#       ? `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/hiroppy_ssr-sample
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/hiroppy_ssr-sample having 95 candidate files.
# Found 2 gql strings in the repository.
# Found 1 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nhn_toast-ui.vue-chart
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nhn_toast-ui.vue-chart having 4 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/SashenJayathilaka_Unique-Project-Ideas
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/SashenJayathilaka_Unique-Project-Ideas having 633 candidate files.
# Found 10 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     getPosts {
#       id
#       body
#       createdAt
#       username
#       likeCount
#       likes {
#         username
#       }
#       commentCount
#       comments {
#         id
#         username
#         createdAt
#         body
#       }
#     }
#   }
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/withspectrum_spectrum
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/withspectrum_spectrum having 1030 candidate files.
# Found 83 gql strings in the repository.
# Found 3 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/shoutem_extensions
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/shoutem_extensions having 3916 candidate files.
# Found 0 gql strings in the repository.
# Found 5 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/katopz_react-apollo-graphql-github-example
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/katopz_react-apollo-graphql-github-example having 6 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/0xHexE_keycloak-hasura-connector
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/0xHexE_keycloak-hasura-connector having 21 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#           {
#             products {
#               id
#               name
#             }
#           }
#         `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/delucis_astro-netlify-cms
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/delucis_astro-netlify-cms having 14 candidate files.
# Found 0 gql strings in the repository.
# Found 1 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/tokopedia_treats
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/tokopedia_treats having 224 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Uniswap_org-v1
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Uniswap_org-v1 having 82 candidate files.
# Found 6 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     uniswapFactory(id: "0x5C69bEe701ef814a2B6a3EDD4B1652CB9cc5aA6f") {
#       totalVolumeUSD
#       totalLiquidityUSD
#       pairCount
#       txCount
#     }
#     bundle(id: 1) {
#       ethPrice
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     uniswapFactory(id: "0x5C69bEe701ef814a2B6a3EDD4B1652CB9cc5aA6f") {
#       totalVolumeUSD
#       totalLiquidityUSD
#       pairCount
#       txCount
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     uniswapFactory(id: "0x5C69bEe701ef814a2B6a3EDD4B1652CB9cc5aA6f") {
#       totalVolumeUSD
#       totalLiquidityUSD
#       pairCount
#     }
#     bundle(id: 1) {
#       ethPrice
#     }
#   }
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/xilibi2003_training_camp_2
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/xilibi2003_training_camp_2 having 65 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/eea-oasis_baseline
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/eea-oasis_baseline having 891 candidate files.
# Found 63 gql strings in the repository.
# Found 1 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/pangolindex_pangolin.exchange
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/pangolindex_pangolin.exchange having 23 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/rigelprotocol_SmartswapDappV2
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/rigelprotocol_SmartswapDappV2 having 253 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/grand-stack_grand-stack-starter
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/grand-stack_grand-stack-starter having 46 candidate files.
# Found 11 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     ratingsCount {
#       stars
#       count
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     reviews(options: { limit: 10, sort: { date: DESC } }) {
#       user {
#         name
#       }
#       business {
#         name
#       }
#       date
#       text
#       stars
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     userCount
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     ratingsCount {
#       stars
#       count
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     reviews(options: { limit: 10, sort: { date: DESC } }) {
#       user {
#         name
#       }
#       business {
#         name
#       }
#       date
#       text
#       stars
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     userCount
#   }
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/42atomys_stud42
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/42atomys_stud42 having 190 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Bayer-Group_ol-kit
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Bayer-Group_ol-kit having 306 candidate files.
# Found 3 gql strings in the repository.
# Found 1 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
# {
#   landpads {
#     location {
#       latitude
#       longitude
#       name
#       region
#     }
#     full_name
#     landing_type
#     attempted_landings
#   }
# }
# `'.
# Unable to extract operation type from GQL section 'gql`
# {
#   launchesPastResult {
#     data {
#       launch_site {
#         site_id
#         site_name_long
#         site_name
#       }
#       launch_date_utc
#     }
#   }
# }
# `'.
# Unable to extract operation type from GQL section 'gql`
# {
#   launchpads {
#     location {
#       latitude
#       longitude
#       name
#       region
#     }
#     name
#     successful_launches
#     vehicles_launched {
#       id
#       cost_per_launch
#     }
#     wikipedia
#     id
#     details
#   }
# }
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Shopify_shopify-demo-app-node-react
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/Shopify_shopify-demo-app-node-react having 9 candidate files.
# Found 2 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/coderplanets_coderplanets_admin
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/coderplanets_coderplanets_admin having 633 candidate files.
# Found 80 gql strings in the repository.
# Found 35 constants in the repository.
# Unable to extract operation type from GQL section 'gql``'.
# Unable to extract operation type from GQL section 'gql``'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.community}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedCategories}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.partialTags}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedThreads}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedPosts}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedJobs}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedRepos}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedVideos}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedUsers}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedCommunities}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedCategories}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedTags}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedThreads}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedPosts}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedJobs}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedRepos}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedVideos}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedThreads}
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/arkhn_pyrog
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/arkhn_pyrog having 135 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/18F_handbook
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/18F_handbook having 21 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/hasura_client-side-graphql
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/hasura_client-side-graphql having 18 candidate files.
# Found 2 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/javamonn_sunspot
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/javamonn_sunspot having 15 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nikgraf_graphql-apollo-client-course
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nikgraf_graphql-apollo-client-course having 31 candidate files.
# Found 17 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     recipes {
#       id
#       title
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#             {
#               recipes {
#                 id
#                 title
#               }
#             }
#           `'.
# Unable to extract operation type from GQL section 'gql`
# //       {
# //         recipes {
# //           id
# //           title
# //         }
# //       }
# //     `'.
# Unable to extract operation type from GQL section 'gql`
#                   {
#                     recipes {
#                       id
#                       title
#                     }
#                   }
#                 `'.
# Unable to extract operation type from GQL section 'gql`
# //   query recipes($vegetarian: Boolean!) {
# //     recipes(vegetarian: $vegetarian) {
# //       id
# //       title
# //     }
# //   }
# // `'.
# Unable to extract operation type from GQL section 'gql`
#       //   fragment isStarredTodo on RecipeItem {
#       //     isStarred
#       //   }
#       // `'.
# Unable to extract operation type from GQL section 'gql`
# //   query recipes($vegetarian: Boolean!) {
# //     recipes(vegetarian: $vegetarian) {
# //       id
# //       title
# //     }
# //   }
# // `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/republik_plattform
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/republik_plattform having 2937 candidate files.
# Found 340 gql strings in the repository.
# Found 23 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#     ${TeaserEmbedComment.data.query}
#   `'.
# Unable to extract operation type from GQL section 'gql`
#     ${TeaserActiveDebates.data.query}
#   `'.
# Unable to extract operation type from GQL section 'gql`
#     ${TeaserMyMagazine.data.query}
#   `'.
# Unable to extract operation type from GQL section 'gql`
#     ${TeaserActiveDebates.data.query}
#   `'.
# Unable to extract operation type from GQL section 'gql`
#     ${TeaserMyMagazine.data.query}
#   `'.
# Unable to extract operation type from GQL section 'gql`
#     ${TeaserEmbedComment.data.query}
#   `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/stealthdrop_stealthdrop
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/stealthdrop_stealthdrop having 90 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/briancaffey_django-postgres-vue-gitlab-ecs
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/briancaffey_django-postgres-vue-gitlab-ecs having 50 candidate files.
# Found 3 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nhn_toast-ui.vue-calendar
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/nhn_toast-ui.vue-calendar having 4 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/saleor_saleor-storefront
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/saleor_saleor-storefront having 898 candidate files.
# Found 26 gql strings in the repository.
# Found 3 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   ${taxedPriceFragment}
#   fragment ProductVariantFields on ProductVariant {
#     id
#     sku
#     name
#     quantityAvailable(countryCode: $countryCode)
#     images {
#       id
#       url
#       alt
#     }
#     pricing {
#       onSale
#       priceUndiscounted {
#         ...TaxedPrice
#       }
#       price {
#         ...TaxedPrice
#       }
#     }
#     attributes(variantSelection: VARIANT_SELECTION) {
#       attribute {
#         id
#         name
#         slug
#       }
#       values {
#         id
#         name
#         value: name
#       }
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${basicProductFragment}
#   ${selectedAttributeFragment}
#   ${productVariantFragment}
#   ${productPricingFragment}
#   query ProductDetails($id: ID!, $channel: String, $countryCode: CountryCode) {
#     product(id: $id, channel: $channel) {
#       ...BasicProductFields
#       ...ProductPricingField
#       description
#       category {
#         id
#         name
#         products(first: 3, channel: $channel) {
#           edges {
#             node {
#               ...BasicProductFields
#               ...ProductPricingField
#             }
#           }
#         }
#       }
#       images {
#         id
#         alt
#         url
#       }
#       attributes {
#         ...SelectedAttributeFields
#       }
#       variants {
#         ...ProductVariantFields
#       }
#       seoDescription
#       seoTitle
#       isAvailable
#       isAvailableForPurchase
#       availableForPurchase
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${basicProductFragment}
#   ${productVariantFragment}
#   query VariantList($ids: [ID!], $channel: String, $countryCode: CountryCode) {
#     productVariants(ids: $ids, first: 100, channel: $channel) {
#       edges {
#         node {
#           ...ProductVariantFields
#           product {
#             ...BasicProductFields
#           }
#         }
#       }
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${productPricingFragment}
#   ${attributeFragment}
#   query SearchProducts(
#     $query: String!
#     $channel: String!
#     $attributes: [AttributeInput]
#     $pageSize: Int
#     $sortBy: ProductOrder
#     $after: String
#   ) {
#     products(
#       channel: $channel
#       filter: { search: $query, attributes: $attributes }
#       first: $pageSize
#       sortBy: $sortBy
#       after: $after
#     ) {
#       totalCount
#       edges {
#         node {
#           ...ProductPricingField
#           id
#           name
#           slug
#           thumbnail {
#             url
#             alt
#           }
#           thumbnail2x: thumbnail(size: 510) {
#             url
#           }
#           category {
#             id
#             name
#           }
#         }
#       }
#       pageInfo {
#         endCursor
#         hasNextPage
#       }
#     }
#     attributes(filter: { filterableInStorefront: true }, first: 100) {
#       edges {
#         node {
#           ...Attribute
#         }
#       }
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${featuredProductsFragment}
#   query FeaturedProductsQuery($channel: String!) {
#     ...FeaturedProducts
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${attributeFragment}
#   query ShopAttributesQuery(
#     $channel: String!
#     $collectionId: ID
#     $categoryId: ID
#   ) {
#     attributes(
#       channel: $channel
#       filter: {
#         inCollection: $collectionId
#         inCategory: $categoryId
#         filterableInStorefront: true
#       }
#       first: 100
#     ) {
#       edges {
#         node {
#           ...Attribute
#         }
#       }
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${menuItemFragment}
#   query ShopMenusQuery(
#     $channel: String!
#     $footerSlug: String!
#     $mainMenuSlug: String!
#   ) {
#     footer: menu(channel: $channel, slug: $footerSlug) {
#       id
#       items {
#         ...MenuItem
#         children {
#           ...MenuItem
#         }
#       }
#     }
#     mainMenu: menu(channel: $channel, slug: $mainMenuSlug) {
#       items {
#         ...MenuItem
#         children {
#           ...MenuItem
#           children {
#             ...MenuItem
#           }
#         }
#       }
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${priceFragment}
#   fragment TaxedPrice on TaxedMoney {
#     gross {
#       ...Price
#     }
#     net {
#       ...Price
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${taxedPriceFragment}
#   fragment ProductPricingField on Product {
#     pricing {
#       onSale
#       priceRangeUndiscounted {
#         start {
#           ...TaxedPrice
#         }
#         stop {
#           ...TaxedPrice
#         }
#       }
#       priceRange {
#         start {
#           ...TaxedPrice
#         }
#         stop {
#           ...TaxedPrice
#         }
#       }
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${basicProductFragment}
#   ${productPricingFragment}
#   fragment FeaturedProduct on Product {
#     ...BasicProductFields
#     ...ProductPricingField
#     category {
#       id
#       name
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${featuredProductFragment}
#   fragment FeaturedProducts on Query {
#     collection(slug: "featured-products", channel: $channel) {
#       id
#       name
#       backgroundImage {
#         url
#       }
#       products(first: 20) {
#         edges {
#           node {
#             ...FeaturedProduct
#           }
#         }
#       }
#     }
#   }
# `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/strues_boldr
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/strues_boldr having 831 candidate files.
# Found 2 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#     {
#       categories {
#         id
#         name
#         slug
#       }
#     }
#   `'.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/apollographql_apollo-link-persisted-queries
# Extracting query-name-pairs from repository /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/apollographql_apollo-link-persisted-queries having 6 candidate files.
# Found 4 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_repos_0_99/infrastructure-components_infrastructure-components
# ...
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/grand-stack_graphql-auth-directives.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/gil--_gatsby-starter-shopify-app.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/graphile_bootstrap-react-apollo.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/Epistimio_orion.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/18F_handbook.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/aws-amplify_amplify-codegen.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/apollographql_apollo-link-persisted-queries.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/functionless_functionless.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/guidone_node-red-contrib-chatbot.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/delucis_astro-netlify-cms.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/m-rgba_hasura-django-starter.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/dotansimha_graphql-code-generator-community.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/javamonn_sunspot.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/withspectrum_spectrum.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/aerogear_offix.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/strapi_strapi-starter-angular-blog.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/Uniswap_api-deprecated.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/SalesforceCommerceCloud_sfcc-sample-apps.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/strues_boldr.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/bandprotocol_bandchain.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/saleor_saleor-storefront.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/kyma-project_console.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/eea-oasis_baseline.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/AztecProtocol_aztec-v1.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/0xHexE_keycloak-hasura-connector.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/aws-samples_lambda-refarch-imagerecognition.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/aws-samples_aws-builders-fair-projects.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/Ninjas-Code-official_Enatega-Restaurant-Solution.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/SashenJayathilaka_Unique-Project-Ideas.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/launchscout_graphql-admin-react.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/awslabs_aws-dataall.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/simarmannsingh_gatsby-netlifycms-modern-blog.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/grand-stack_grand-stack-starter.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/hasura_json2graphql.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/System-Glitch_Solidity-IDE.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/adieuadieu_retinal.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/stealthdrop_stealthdrop.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/henry40408_awesome-stars.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/nhost_nhost.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/republik_plattform.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/arkhn_pyrog.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/DidoMarchet_starter-kit-nuxt-locomotive-scroll.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/replicatedhq_kots.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/pangolindex_pangolin.exchange.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/starknet-io_starknet-website.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/Shopify_product-reviews-sample-app.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/nikgraf_graphql-apollo-client-course.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/infrastructure-components_infrastructure-components.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/delegatable_MobyMask.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/alytrics_yaba-social.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/coderplanets_coderplanets_admin.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/aragon_aragon-apps.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/aws-amplify_amplify-category-api.yaml
# Found query file /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_queries_0_99/katopz_react-apollo-graphql-github-example.yaml
# Generate negative dataset
# Positive dataset:
# [{"type": "query", "name": "($id: String!)", "content": "{\n    User(where: { id: { _eq: $id } }) {\n      email\n      avatar\n      last_seen\n      name\n      Posts_aggregate {\n        aggregate {\n          count\n        }\n      }\n    }\n    Post(where: { user_id: { _eq: $id } }) {\n      url\n      caption\n      id\n    }\n  }"}, {"type": "query", "name": "($id: String!)", "content": "{\n    Follow_aggregate(where: { follower_id: { _eq: $id } }) {\n      aggregate {\n        count\n      }\n    }\n  }"}, {"type": "query", "name": "($id: String!)", "content": "{\n    Follow_aggregate(where: { following_id: { _eq: $id } }) {\n      aggregate {\n        count\n      }\n    }\n  }"}, {"type": "query", "name": "($id: Int!, $userId: String!)", "content": "{\n    Post(where: { id: { _eq: $id } }) {\n      Likes_aggregate {\n        aggregate {\n          count\n        }\n      }\n      Likes(where: { user_id: { _eq: $userId } }) {\n        id\n      }\n    }\n  }"}, {"type": "mutation", "name": "($postId: Int!, $userId: String!)", "content": "{\n    insert_Like(objects: [{ post_id: $postId, user_id: $userId }]) {\n      affected_rows\n    }\n  }"}, {"type": "mutation", "name": "($postId: Int!, $userId: String!)", "content": "{\n    delete_Like(\n      where: { user_id: { _eq: $userId }, post_id: { _eq: $postId } }\n    ) {\n      affected_rows\n    }\n  }"}, {"type": "mutation", "name": "($url: String!, $userId: String!, $caption: String!)", "content": "{\n    insert_Post(objects: { url: $url, caption: $caption, user_id: $userId }) {\n      affected_rows\n    }\n  }"}, {"type": "query", "name": "($followingId: String!, $userId: String!)", "content": "{\n    Follow(\n      where: {\n        follower_id: { _eq: $userId }\n        following_id: { _eq: $followingId }\n      }\n    ) {\n      id\n    }\n  }"}, {"type": "mutation", "name": "($followingId: String!, $userId: String!)", "content": "{\n    insert_Follow(\n      objects: [{ follower_id: $userId, following_id: $followingId }]\n    ) {\n      affected_rows\n    }\n  }"}, {"type": "mutation", "name": "($followingId: String!, $userId: String!)", "content": "{\n    delete_Follow(\n      where: {\n        follower_id: { _eq: $userId }\n        following_id: { _eq: $followingId }\n      }\n    ) {\n      affected_rows\n    }\n  }"}, {"type": "query", "name": "($id: Int!)", "content": "{\n    Post(where: { id: { _eq: $id } }) {\n      id\n      caption\n      created_at\n      url\n      User {\n        avatar\n        id\n        name\n      }\n    }\n  }"}, {"type": "query", "name": "GetMode", "content": "{\n                        mode @client\n                    }"}, {"type": "query", "name": "GetFavorites", "content": "{\n                        favorites @client\n                    }"}, {"type": "query", "name": "GetFavorites", "content": "{\n                        favorites @client\n                    }"}, {"type": "query", "name": "GetWatched", "content": "{\n                        watched @client\n                    }"}, {"type": "query", "name": "GetWatched", "content": "{\n                        watched @client\n                    }"}, {"type": "query", "name": "GetFavorites", "content": "{\n        favorites @client\n    }"}, {"type": "query", "name": "GetWatched", "content": "{\n        watched @client\n    }"}, {"type": "query", "name": "allVideos($search: String)", "content": "{\n        _allVideosesMeta(\n            filter: { isPublished: true, name_contains: $search }\n        ) {\n            count\n        }\n    }"}, {"type": "mutation", "name": "createVideos(\n        $name: String!\n        $link: String!\n        $moderatorNotes: String\n    )", "content": "{\n        createVideos(\n            name: $name\n            link: $link\n            moderatorNotes: $moderatorNotes\n        ) {\n            id\n            name\n        }\n    }"}, {"type": "query", "name": "tagVideosw($name: String)", "content": "{\n        allTagses(filter: { name ...
# Negative dataset:
# [{"type": "query", "name": "MatchQuery($match_id: Int, $match_uuid: String)", "content": "{\n    login(facebookId:$facebookId,email:$email,password:$password,type:$type,appleId:$appleId,name:$name,notificationToken:$notificationToken){\n     userId\n     token\n     is_active\n     tokenExpiration\n     name\n     email\n     phone\n   }\n}"}, {"type": "query", "name": "repoMilestones($repoId: ID!)", "content": "{\n  restaurantByOwner(id:$id){\n  _id\n  email\n  userType\n  restaurants{\n    _id\n    orderId\n    orderPrefix\n    name\n    slug\n    image\n    address\n    username\n    password\n    location{coordinates}\n    }\n  }\n}"}, {"type": "mutation", "name": "resubscribeEmail($userId: ID!)", "content": "{\n    questionnaire(slug: $slug) {\n      ...QuestionnaireFragment\n      results: submissions(\n        search: $search\n        first: $first\n        after: $after\n        sort: { by: $sortBy, direction: $sortDirection }\n        filters: { answers: $answers, id: $id, userIds: $userIds }\n      ) {\n        totalCount\n        pageInfo {\n          endCursor\n          hasNextPage\n        }\n        nodes {\n          ...QuestionnaireSubmissionFragment\n        }\n      }\n    }\n  }\n  ${questionnaireData}\n  ${submissionData}"}, {"type": "mutation", "name": "updateStack($targetUri: String!, $targetType: String!)", "content": "{\n      removeGroupFromOrganization(\n        organizationUri: $organizationUri\n        groupUri: $groupUri\n      ) {\n        organizationUri\n      }\n    }"}, {"type": "query", "name": "WalletLinker", "content": "{\n      createPostConnection(input: { title: \"Hello, World!\" }) {\n        id\n        title\n      }\n    }"}, {"type": "query", "name": "GetDatasetAssumeRoleUrl($datasetUri: String!)", "content": "{\n      syncTables(datasetUri: $datasetUri) {\n        count\n        nodes {\n          tableUri\n          GlueTableName\n          GlueDatabaseName\n          description\n          name\n          label\n          created\n          S3Prefix\n          dataset {\n            datasetUri\n            name\n            GlueDatabaseName\n            userRoleForDataset\n          }\n        }\n      }\n    }"}, {"type": "subscription", "name": "OnCreateTodo", "content": "{\n      createTerm(parentUri: $parentUri, input: $input) {\n        nodeUri\n        label\n        path\n        readme\n        created\n        owner\n      }\n    }"}, {"type": "mutation", "name": "SendFromWallet($from: String, $to: String, $value: String)", "content": "{\n    signOut\n  }"}, {"type": "subscription", "name": "oAuthClientEvent($namespace: String!)", "content": "{\n          feed {\n            ...FeedWithRepository\n          }\n        }\n\n        ${feedWithRepository}"}, {"type": "query", "name": "ListWorksheets($filter: WorksheetFilter)", "content": "{\n      enableDataSubscriptions(environmentUri: $environmentUri, input: $input)\n    }"}, {"type": "subscription", "name": "OnDeleteStudent", "content": "{\n    application(id: $id) {\n      id\n      providerName\n      description\n      name\n      labels\n      healthCheckURL\n      integrationSystemID\n      status {\n        condition\n      }\n      packages {\n        data {\n          id\n          name\n          description\n          defaultInstanceAuth {\n            credential {\n              __typename\n            }\n          }\n          apiDefinitions {\n            totalCount\n          }\n          eventDefinitions {\n            totalCount\n          }\n        }\n      }\n    }\n  }"}, {"type": "subscription", "name": "ServiceBindingUsageEvent($namespace: String!)", "content": "{\n    createRef(input: $createRefInput) {\n      branch: ref {\n        ...BranchParts\n      }\n    }\n    ${createPullRequestMutationPart}\n  }\n  ${fragments.branch}\n  ${fragments.pullRequest}"}, {"type": "mutation", "name": "CreateTodo($input: CreateTodoInput!)", "content": "{\n    assignedOrders(id:$id){\n      _id\n      rider{\n    ...
