# %%
# !pip install gitpython
# %mkdir /content/data_collection
# %cd /content/data_collection
# !git clone https://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@github.com/Logende/GraphQLQueryNameConsistency.git
# %cd GraphQLQueryNameConsistency/dataset_generator
# !python3 dataset_generator/generator_toolchain.py 100 199

# %%
# !python3 dataset_generator/generator_toolchain.py 100 199
# Out:
# Start generator toolchain with repo 100 to 199.
# Create subset of dependents file: /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_dependents_100_199/dependents_apollo-client.csv
# Clone repos
# Begin endless cloning process.
# Attempt cloning of Github Repos.
# Start cloning Repo contentful/template-marketing-webapp-nextjs.
# Start cloning Repo rossmc/how-to-venia.
# Start cloning Repo udacity/live-codings-react-nanodegree.
# Start cloning Repo perpetual-protocol/perp-curie-arbitrageur.
# Start cloning Repo Shopify/shopify-marketplaces-buyer-app.
# Start cloning Repo redochka/nextjs-shopify-app-no-custom-server.
# Start cloning Repo openline-ai/openline-customer-os.
# Start cloning Repo CaptainFact/captain-fact-extension.
# Start cloning Repo FormidableLabs/graphql-typescript-blog.
# Start cloning Repo orangeloops/public-ol-native-template.
# Start cloning Repo theogravity/graphql-apollo-server-client-example.
# ...

# %%
# !python3 dataset_generator/generator_toolchain.py 600 699
# Out:
# Start generator toolchain with repo 600 to 699.
# Create subset of dependents file: /content/data_collection/GraphQLQueryNameConsistency/dataset_generator/collected_dependents_600_699/dependents_apollo-client.csv
# Clone repos
# Begin endless cloning process.
# Attempt cloning of Github Repos.
# Start cloning Repo byCedric/GitHub-Website-legacy.
# Start cloning Repo unitythemaker/blog-themaker.
# Start cloning Repo stem-discord/website.
# Start cloning Repo MX56893/restaurant-food-delivery-v2.
# Start cloning Repo readr-media/open-relationship.
# Start cloning Repo tongchengbin/ocean_manager.
# Start cloning Repo greatWall627/prismaEcommerce.
# Start cloning Repo eveisesi/neo-ui.
# Start cloning Repo bjerkio/stact.
# Start cloning Repo aerogear/offix-react-native-example.
# Start cloning Repo hygorchristian/Music-Player-Web.
# Start cloning Repo jackleslie/dydx-subgraph-frontend.
# Start cloning Repo robinsimonklein/mabellemort.
# Start cloning Repo Jahia/dx-react-starter.
# ...
