# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Dataset generation

# %%
# !pip install gitpython
# Out:
# Collecting gitpython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 4.6 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.10 gitpython-3.1.31 smmap-5.0.0

# %%
# %cd drive/MyDrive/asdl_project/dataset_generator
# Out:
# /content/drive/MyDrive/asdl_project/dataset_generator

# %%
#!git clone https://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@github.com/Logende/GraphQLQueryNameConsistency.git

# %%
#!git reset --hard
# Out:
# Updating files: 100% (4262/4262), done.

# %%
# !python3 dataset_generator/clone_dependent_repos.py
# Out:
# Begin endless cloning process.
# Attempt cloning of Github Repos.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/withspectrum_spectrum already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nhost_nhost already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ashutosh1919_masterPortfolio already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Canner_cannercms already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/datopian_portaljs already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/42atomys_stud42 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/guidone_node-red-contrib-chatbot already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/replicatedhq_kots already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SaraVieira_awesome-talks already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/saleor_saleor-storefront already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aerogear_offix already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-samples_lambda-refarch-imagerecognition already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/OriginProtocol_origin already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/AztecProtocol_aztec-v1 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/eea-oasis_baseline already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/apollographql_reason-apollo already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/grand-stack_grand-stack-starter already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Shopify_shopify-demo-app-node-react already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aragon_aragon-apps already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/manikandanraji_twitter-clone-frontend already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/functionless_functionless already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/stealthdrop_stealthdrop already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/apollographql_apollo-link-persisted-queries already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/FormidableLabs_seattlejsconf-app already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Shopify_product-reviews-sample-app already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hiroppy_ssr-sample already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Epistimio_orion already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/stackrole_gatsby-starter-foundation already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/bandprotocol_bandchain already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/shoutem_extensions already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/adieuadieu_retinal already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Ninjas-Code-official_Enatega-Restaurant-Solution already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hasura_json2graphql already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nhn_toast-ui.vue-calendar already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nervosnetwork_muta already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/awslabs_aws-dataall already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/tokopedia_treats already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hasura_client-side-graphql already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Uniswap_org-v1 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/alytrics_yaba-social already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/4GeeksAcademy_Templates-Boilerplates already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/delucis_astro-netlify-cms already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SalesforceCommerceCloud_sfcc-sample-apps already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/katopz_react-apollo-graphql-github-example already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/grand-stack_graphql-auth-directives already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/LFSCamargo_Chatify already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/docker-hy_docker-hy.github.io already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/18F_handbook already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/0xHexE_keycloak-hasura-connector already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/gil--_gatsby-starter-shopify-app already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/gil--_gatsby-starter-shopifypwa already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/infrastructure-components_infrastructure-components already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/starknet-io_starknet-website already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DidoMarchet_starter-kit-nuxt-locomotive-scroll already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/System-Glitch_Solidity-IDE already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Uniswap_api-deprecated already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-samples_aws-builders-fair-projects already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/BuidlGuidl_abi.ninja already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/realm_realm-graphql already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/henry40408_awesome-stars already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/strues_boldr already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/lumen-cms_lumen-cms already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/denniske_aoe2companion already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Ninjas-Code-official_Marketplace-Food-Delivery-Solution already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Bayer-Group_ol-kit already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/monopayments_iban.im already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/strapi_strapi-starter-angular-blog already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/javamonn_sunspot already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/xilibi2003_training_camp_2 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/kubernetes-hy_kubernetes-hy.github.io already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/m-rgba_hasura-django-starter already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/vgrafe_nextjs-auth0-hasura already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hygraph_example_01_nextjs_apollo already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nerdify_db-schema-diagram already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-amplify_amplify-category-api already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SashenJayathilaka_Unique-Project-Ideas already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/briancaffey_django-postgres-vue-gitlab-ecs already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/gitcoinco_passport-sdk already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/IndexCoop_index-ui already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/arkhn_pyrog already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/rigelprotocol_SmartswapDappV2 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nikgraf_graphql-apollo-client-course already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aerogear_datasync-voyager already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-amplify_amplify-codegen already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nhn_toast-ui.vue-chart already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/chaoss_grimoirelab-sortinghat already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/launchscout_graphql-admin-react already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/usecannon_cannon already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/graphile_bootstrap-react-apollo already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dotansimha_graphql-code-generator-community already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/AISHU-Technology_kweaver already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/delegatable_MobyMask already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/keystonejs_keystone-jamstack-plus already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/coderplanets_coderplanets_admin already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/abhi40308_instagram-clone already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/kyma-project_console already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/simarmannsingh_gatsby-netlifycms-modern-blog already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/republik_plattform already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/pangolindex_pangolin.exchange already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/contentful_template-marketing-webapp-nextjs already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/rossmc_how-to-venia already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/udacity_live-codings-react-nanodegree already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/perpetual-protocol_perp-curie-arbitrageur already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Shopify_shopify-marketplaces-buyer-app already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/redochka_nextjs-shopify-app-no-custom-server already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/openline-ai_openline-customer-os already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/CaptainFact_captain-fact-extension already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/FormidableLabs_graphql-typescript-blog already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/orangeloops_public-ol-native-template already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/theogravity_graphql-apollo-server-client-example already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nayms_contracts-v2 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/vendure-ecommerce_gatsby-storefront already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/philbir_magic-media already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/open-condo-software_condo already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Fernanda-Kipper_challenge-frontend already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/craigmulligan_clementine already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/jk-labs-inc_jokerace already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ChorusOne_anthem already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/EddiG_ssr-cra-graphql already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/stevenpslade_scaffold-eth-tailwind already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/AztecProtocol_aztec-v1-loan-dapp already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Atom-Learning_components already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Project-Gutenberg_Pincong-data already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/cloud-gov_pages-uswds-gatsby already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/platelet-app_platelet already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/atbcb_ICTTestingBaseline already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Evavic44_rocketmeme already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/spawnfest_elixirbench already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Vikash-8090-Yadav_SaL--dApp already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dstrekelj_algebra-front-end-developer-course-workbook already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/paritytech_Nomidot already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ThatConference_that-website already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/29ki_29k already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/deliteser112_meteor-starter-kit already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/COS-301_graduates already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/tweag_nix-hour already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/xuwaters_editor.sh already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Yolk-HQ_next-utils already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/paritytech_polkassembly already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/mathculthello_savva3 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/orangeloops_public-ol-web-template already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/sangheili868_StarWars5e.Site already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SaTT-Wallet_Backend already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/muratkeremozcan_books already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dfuse-io_docs already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/webiny_write-with-webiny already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/perspect3vism_ad4m already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/usecannon_cannon-legacy already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DocNow_catalog already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/egoist_list.egoist.sh already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/zendesk_volunteer_portal already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/mozilla-iam_dino-park-front-end already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/datagrok-ai_public already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/tfabritius_pr already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/atomist_org-visualizer already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/heejongahn_blog already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/zzy_actix-graphql-react already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/scaffold-eth_punk-wallet already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Zenysis_Harmony already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/WWCodeTokyo_speak-her-db already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/bgoonz_awesome-4-new-developers already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/WestpacGEL_GEL already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/lcfr-eth_FlashbotsBundlerUI already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/robertrouse_theographic-web already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Vrishtrix_fullstack-ts-boilerplate already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/d-513_npm-all-packages already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/kata-containers_www.katacontainers.io already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/mrdulin_apollo-graphql-tutorial already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/kalwalt_gatsby-starter-i18n-bulma already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/p1ass_graphql-redis-realtime-chat already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DAB0mB_HotnCold already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/VitorLuizC_dev-demands already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/automatica-core_automatica already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/awslabs_amplify-graphql-seed-plugin already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/pixeljar_local-addon-xdebug-vscode already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/perpetual-protocol_perp-maker already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/UOA-CS732-SE750-Students-2022_project-group-magenta-mice already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/KATT_graphql-workshop already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/NoQuarterTeam_split already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/mahendrasaikumargandham_portfolio already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/iTwin_viewer already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/contentful_the-example-app.graphql.js already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/licensebat_licensebat already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/launchscout_graphql-admin already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Project-Gutenberg_nCovMemory-Web already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/devondragon_SpringShopifyAppFramework already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/clean-commit_gatsby-starter-henlo already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Polygon-Academy_basicnfts already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/phamhongphuc_uit.hotel already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Colm3na_polkastats-v3 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/uw-labs_flaggio already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/atomist_cli already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/moonshotcollective_drecruit already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/3perf_website already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/rage_ohjelmointi-19 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ocftw_open-star-ter-village already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HausDAO_daohaus-web already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/getflywheel_local-addon-atlas already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ericsdevblog_django-vue-starter-blog already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/imodeljs_frontend-sample-showcase already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/anirudhvs_pragyan-ctf-22 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/broxus_ton-dex already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ictsc_ictsc-score-server already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/yinMrsir_typescript-admin already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/CityOfBoston_digital already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hyd628_delegation-dao-demo already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/brave_ads-ui already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Popcorn-moe_Web already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SwissLife-OSS_IdOps already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/councilofelders_numerbay already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/agiledev0115_meteor-boilerplate already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/renproject_command-center already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/orbiting_publikator-frontend already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/thomaswangio_react-producthunt already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/wani-hackase_wanictf21spring-writeup already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/libero_reviewer-submission already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aerogear_graphql-testx already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SwissLife-OSS_Boost already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/TopSpeed1017_spiritswap-frontend already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/BestCryptoKnight_react-admin-with-material-ui-next already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/atomist_sdm-pack-aspect already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/skovy_graphql-blog-client already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/terryyyz_CodeBaseFrontendReactjs already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/feedadoc_feedadoc already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-samples_aws-appsync-presence-api already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hashicorp_learn-terraform-preview-environment already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Yash621_meta-meet already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/naji0329_test-nft-project already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/department-stockholm_apollo-component already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/bloxapp_awesome-ssv already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HappyDream0317_impermax-x-uniswap-v2-interface already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HappyDream0317_Microservices-GrowLabs already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HappyDream0317_self-serve-mint already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/reservoirprotocol_seaport-oracle already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Laravel-VPN-Admin_api-core already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/karimould_minimal-multi-language-gatsby-starter-netlify-cms already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/getflywheel_local-addon-notes already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/getflywheel_local-addon-image-optimizer already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/deliteser112_idie-device-rolls already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/imodeljs_itwin-viewer already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dong-dohai_serverless-content-encoding already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/thestuntcoder_europratsya already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/mgx5kw_MistyDAO already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dm-drogeriemarkt_lisa already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/danielwii_asuna-admin already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/chainsauce-org_chainsauce already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DoBestMan_Bondswap-backend already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/RyanCCollins_ryancollinsio already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Akord-com_akord-js already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nguyentung9820_DEX already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Meeovi_Collaborrate already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/stevenpslade_maas already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/deliteser112_meteor-boiler-plate-app already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ssteiger_minimal-dao already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/0xTranqui_lostandfound-zora-marketplace already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/bhargavaparoksham_scaffold-eth-lens-starter-kit already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/bcgov_digital.gov.bc.ca already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/yamapyblack_CryptoFrontier already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/alibaba-archive_serverless already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/kyma-incubator_varkes already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/samarjaffal_wuptick-frontend already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Vandivier_devfit already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DoBestMan_PrepDD already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/h-REA_holo-rea-proto already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/getflywheel_local-addon-boilerplate already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/malgamves_GameOfCharts already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/bgoonz_React_Notes_V3 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Jckhe_playBoards-ts already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/setsun_react-koa-universal already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/cid-harvard_growth-lab-app-front-end already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/parity-asia_hackathon-2022-summer already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/shafayeatsumit_rugged-multisig already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ruleslabs_interface already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/oumoussa98_leeters already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/impactasaurus_app already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ziggy6792_cdk-monorepo-example-backend already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/newsguildny_nytimesguild.org already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/sumit-mahajan_generative-nft-interface already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/wslyvh_buidl-explorer already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/tomrutgers_middleman-webpack-netlify-cms already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/impactMarket_mobile-app already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DoBestMan_spectrum already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/sazzer_pusher-mud already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Open-NC_reentry-resources-hub already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-samples_realtime-slot-car-racing-with-aws-amplify-aws-iot-core-and-amazon-kinesis-video-streams already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aaronksaunders_amplify-remix-todos-1 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/wednesday-solutions_react-graphql-ts-template already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/collinsmuriuki_covid-19-monitor already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DeltaPrimeLabs_deltaprime-primeloans already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/heyrict_cindy-realtime already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/tylim88_Create-Prisma-App already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/zapkub_cu-vivid-museum-wiki already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Shopify_fulfillment-order-sample-app already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/treejer_web already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SkyCaptainess_Shopify-nextjs already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/mrdulin_react-apollo-graphql-starter-kit already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/crewnew-git_sveltekit-hasura-docker already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Russell1130_decentral-staking already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/mwhorse46_uoona already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/CoCo-27_-nextjs-graphql-adminpanel already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Superdev0103_react-graph-demo already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nativesintech_native-owned-businesses already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/WorkingFamilies_Spoke_legacy already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/getflywheel_local-addon-xdebug-phpstorm already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DanieleSalatti_gitcoin-grants-conviction already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/marian2js_finsharing already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/OtterClam_otter-frontend already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/atomist_uhura already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aciura_Solidity-Marketplace-Dapp already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/michey85_apollo-qql-todos already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/austintgriffith_banana-auction already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/amclin_react-project-boilerplate already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/BlockedTODO_BlockedTODO already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/0xTranqui_lostandfound-optimism-marketplace already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/deliteser112_meteor-graphql-react-device already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/bedwarsify_bedwarsify-overlay already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dtan4_ec2-event-slack-notifier already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/getflywheel_local-addon-instant-reload already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/snipcart_Strapi-Nuxt-Snipcart already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/stvkoch_graphqlizejs already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ruoduan-hub_my-Gatsby-Blog already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/StarlingXWeb_starlingx-website already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/my-lambda-projects_Lambda already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/newjersey_navigator.business.nj.gov already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/rage_ohjelmointi-20 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/pmbanugo_graphql-angular-intro already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/VitroidFPV_VitroidFPV already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Zilliqa_devex already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/BlossomLabs_osmotic-funding already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/PrefectHQ_memory-graphql already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dan2dev_DefinitelyTyped already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/holochain-open-dev_social-triangulation already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Jarred-Sumner_yeet already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/PolymerLabs_project-health already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DekodeInteraktiv_localwp-projectbase-addon already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/uq-its-ss_design-system already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dukedaily_subgraph-demo-dapp already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/spokestack_node-spokestack already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/amenabe22_chewata already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Aakashdeveloper_july_react_eveng_22 already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/PabloSzx_graphql-tag-ts already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Troplo_Colubrina already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hacknlove_onGet already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/meabed_gqlts already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/getflywheel_local-addon-backups already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/lupas_vuetify-i18n-language-switcher-nuxt already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/centrifuge_tinlake-ui already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dferber90_lovely-webapp already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/netlify_netlify-dev-gatsby-fauna-demo already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/haticekatranci_one-click-hugo-cms already exists. Not cloning again.
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/broxus_ever-wever already exists. Not cloning again.
# Start cloning Repo bgoonz/UsefulResourceRepo2.0.
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/subprocess.py", line 1154, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 2021, in _communicate
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/asdl_project/dataset_generator/dataset_generator/clone_dependent_repos.py", line 29, in <module>
#     repo = Repo.clone_from("https://github.com/" + repo_name, result_folder)
#   File "/usr/local/lib/python3.10/dist-packages/git/repo/base.py", line 1325, in clone_from
#     return cls._clone(
#   File "/usr/local/lib/python3.10/dist-packages/git/repo/base.py", line 1229, in _clone
#     (stdout, stderr) = proc.communicate()
#   File "/usr/lib/python3.10/subprocess.py", line 1165, in communicate
#     self._wait(timeout=sigint_timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 1949, in _wait
#     remaining = self._remaining_time(endtime)
# KeyboardInterrupt
# ^C

# %%
# !python3 dataset_generator/extract_gql_queries.py
# Out:
# Folder /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries already exists.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HappyDream0317_Microservices-GrowLabs
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HappyDream0317_Microservices-GrowLabs having 1142 candidate files.
# Found 41 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     all_appointments {
#       id
#       date
#       startTime
#       morningOrEvening
#       endTime
#       duration
#       price
#       esthetician
#       treatments {
#         name
#         duration
#         price
#       }
#       addOns {
#         name
#         duration
#         price
#       }
#       client {
#         _id
#         squareCustomerId
#         unsavedSquareCardIDs
#         firstName
#         lastName
#         email
#         phoneNumber
#       }
#       bookedWithCardSquareID
#       notes
#       confirmed
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     employees {
#       firstName
#       lastName
#       email
#       phoneNumber
#       _id
#       password
#       permanentPasswordSet
#       employeeRole
#       profilePicture
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     clients {
#       squareCustomerId
#       unsavedSquareCardIDs
#       firstName
#       lastName
#       email
#       phoneNumber
#       profilePicture
#       tokenCount
#       consentForm {
#         date
#         surgeryLast3Months
#         surgeryLast3MonthsNotes
#         anyHealthProblems
#         anyHealthProblemsNotes
#         listAnyMedications
#         chemPeelsLastMonth
#         waxingOnFaceLast5Days
#         accutaneOrPrescription
#         accutaneOrPrescriptionNotes
#         anyProductsContainingSalicyclicAcid
#         anyProductsContainingGlycolicAcid
#         anyProductsContainingLacticAcid
#         anyProductsContainingExfoliatingScrubs
#         anyProductsContainingVitaminA
#         fillersOrBotox
#         fillersOrBotoxNotes
#         listKnownAllergies
#         skinFlakyOrItch
#         everDiagnosedWithRosacea
#         pregnantOrNursing
#         ultimateSkinCareGoals
#         anythingElseWeShouldKnow
#         consentFormSignature
#         createdAt
#       }
#       _id
#       password
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     all_personal_events {
#       _id
#       title
#       notes
#       staff
#       date
#       startTime
#       endTime
#       duration
#       allDay
#       blockTime
#     }
#   }
# `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Evavic44_rocketmeme
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Evavic44_rocketmeme having 67 candidate files.
# Found 5 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Fernanda-Kipper_challenge-frontend
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Fernanda-Kipper_challenge-frontend having 36 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/FormidableLabs_graphql-typescript-blog
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/FormidableLabs_graphql-typescript-blog having 20 candidate files.
# Found 3 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     getCharacters(sortDirection: ASC) {
#       id
#       name
#       playedBy
#       culture
#       allegiances {
#         name
#       }
#       isAlive
#     }
#   }
# `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/FormidableLabs_seattlejsconf-app
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/FormidableLabs_seattlejsconf-app having 3 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HappyDream0317_impermax-x-uniswap-v2-interface
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HappyDream0317_impermax-x-uniswap-v2-interface having 246 candidate files.
# Found 14 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`{
#     lendingPools(first: 1000, orderBy: totalBorrowsUSD, orderDirection: desc) {
#       id
#       borrowable0 ${borrowableStr}
#       borrowable1 ${borrowableStr}
#       collateral {
#         id
#         totalBalance
#         totalBalanceUSD
#         safetyMargin
#         liquidationIncentive
#         exchangeRate
#       }
#       pair {
#         reserve0
#         reserve1
#         reserveUSD
#         token0Price
#         token1Price
#         derivedUSD
#       }
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     blocks (first: 1, orderBy: timestamp, orderDirection: desc, where: { timestamp_gt: ${timestamp}, timestamp_lt: ${timestamp + 600} }) {
#       number
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     pairs ( block: {number: ${blockNumber}} where: { id_in: [${addressString}]} ) {
#       id
#       volumeUSD
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     pairs ( where: { id_in: [${addressString}]} ) {
#       id
#       reserveUSD
#       volumeUSD
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     user(id: "${account.toLowerCase()}") {
#       collateralPositions(first:1000) {
#         balance
#         collateral {
#           lendingPool {
#             id
#           }
#         }
#       }
#       supplyPositions(first:1000) {
#         balance
#         borrowable {
#           underlying {
#             id
#           }
#           lendingPool {
#             id
#           }
#         }
#       }
#       borrowPositions(first:1000) {
#         borrowBalance
#         borrowIndex
#         borrowable {
#           underlying {
#             id
#           }
#           lendingPool {
#             id
#           }
#         }
#       }
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#   reservesDistributors(first:1) {
#     balance
#     periodLength
#     lastClaim
#     distributed
#   }
# }`'.
# Unable to extract operation type from GQL section 'gql`{
#     lendingPool(id: "${lowerCasedUniswapV2PairAddress}") {
#       id
#       borrowable0 ${borrowableStr}
#       borrowable1 ${borrowableStr}
#       collateral {
#         id
#         totalBalance
#         totalBalanceUSD
#         safetyMargin
#         liquidationIncentive
#         exchangeRate
#       }
#       pair {
#         reserve0
#         reserve1
#         reserveUSD
#         token0Price
#         token1Price
#         derivedUSD
#       }
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#   impermaxFactories(first: 1) {
#     totalBalanceUSD
#     totalSupplyUSD
#     totalBorrowsUSD
#   }
# }`'.
# Unable to extract operation type from GQL section 'gql`{
#     user(id: "${account.toLowerCase()}") {
#       ximxBalance
#       lastExchangeRate
#       totalEarned
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#   ximxes(first: 1) {
#     totalSupply
#     totalBalance
#     exchangeRate
#     dailyAPR
#   }
# }`'.
# Unable to extract operation type from GQL section 'gql`{
#   lendingPools(first: 1000, orderBy: totalBorrowsUSD, orderDirection: desc) {
#     id
#     borrowable0 ${borrowableStr}
#     borrowable1 ${borrowableStr}
#     collateral {
#       id
#       totalBalance
#       totalBalanceUSD
#       safetyMargin
#       liquidationIncentive
#       exchangeRate
#     }
#     pair {
#       reserve0
#       reserve1
#       reserveUSD
#       token0Price
#       token1Price
#       derivedUSD
#     }
#   }
# }`'.
# Unable to extract operation type from GQL section 'gql`{
#     blocks (first: 1, orderBy: timestamp, orderDirection: desc, where: { timestamp_gt: ${timestamp}, timestamp_lt: ${timestamp + 600} }) {
#       number
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     pairs ( block: {number: ${blockNumber}} where: { id_in: [${addressString}]} ) {
#       id
#       volumeUSD
#     }
#   }`'.
# Unable to extract operation type from GQL section 'gql`{
#     pairs ( where: { id_in: [${addressString}]} ) {
#       id
#       reserveUSD
#       volumeUSD
#     }
#   }`'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HappyDream0317_self-serve-mint
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HappyDream0317_self-serve-mint having 66 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HausDAO_daohaus-web
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/HausDAO_daohaus-web having 89 candidate files.
# Found 9 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Laravel-VPN-Admin_api-core
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Laravel-VPN-Admin_api-core having 7 candidate files.
# Found 11 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Meeovi_Collaborrate
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Meeovi_Collaborrate having 357 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/IndexCoop_index-ui
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/IndexCoop_index-ui having 324 candidate files.
# Found 2 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     pairs(where: { id: "${uniswapEthDpiLpTokenAddress}" }) {
#       id
#       reserveUSD
#       totalSupply
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     pairs(where: { id: "${uniswapEthMviLpTokenAddress}" }) {
#       id
#       reserveUSD
#       totalSupply
#     }
#   }
# `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/LFSCamargo_Chatify
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/LFSCamargo_Chatify having 43 candidate files.
# Found 16 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/0xTranqui_lostandfound-zora-marketplace
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/0xTranqui_lostandfound-zora-marketplace having 65 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/withspectrum_spectrum
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/withspectrum_spectrum having 1030 candidate files.
# Found 83 gql strings in the repository.
# Found 3 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ashutosh1919_masterPortfolio
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/ashutosh1919_masterPortfolio having 20 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Canner_cannercms
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Canner_cannercms having 463 candidate files.
# Found 16 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`${gqlStr}`'.
# Unable to extract operation type from GQL section 'gql`${schema[rootKey].graphql}`'.
# Unable to extract operation type from GQL section 'gql`${this.query.toGQL(actions[0].payload.key)}`'.
# Unable to extract operation type from GQL section 'gql`${mutation}`'.
# Unable to extract operation type from GQL section 'gql`${this.query.toGQL(key)}`'.
# Unable to extract operation type from GQL section 'gql`${schema[rootKey].graphql}`'.
# Unable to extract operation type from GQL section 'gql`${this.query.toGQL(actions[0].payload.key)}`'.
# Unable to extract operation type from GQL section 'gql`${query.toGQL(keyName)}`'.
# Unable to extract operation type from GQL section 'gql`${graphql}`'.
# Unable to extract operation type from GQL section 'gql`${graphql}`'.
# Unable to extract operation type from GQL section 'gql`${gqlStr}`'.
# Unable to extract operation type from GQL section 'gql`${query.toGQL(key)}`'.
# Unable to extract operation type from GQL section 'gql`${query}`'.
# Unable to extract operation type from GQL section 'gql`${mutation}`'.
# Unable to extract operation type from GQL section 'gql`${mutation}`'.
# Unable to extract operation type from GQL section 'gql`${mutation}`'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/datopian_portaljs
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/datopian_portaljs having 2 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/42atomys_stud42
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/42atomys_stud42 having 186 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/replicatedhq_kots
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/replicatedhq_kots having 18 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SaraVieira_awesome-talks
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SaraVieira_awesome-talks having 9 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/saleor_saleor-storefront
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/saleor_saleor-storefront having 8 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aerogear_offix
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aerogear_offix having 2 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-samples_lambda-refarch-imagerecognition
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-samples_lambda-refarch-imagerecognition having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/AztecProtocol_aztec-v1
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/AztecProtocol_aztec-v1 having 1041 candidate files.
# Found 13 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/apollographql_reason-apollo
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/apollographql_reason-apollo having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/grand-stack_grand-stack-starter
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/grand-stack_grand-stack-starter having 6 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Shopify_shopify-demo-app-node-react
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Shopify_shopify-demo-app-node-react having 9 candidate files.
# Found 2 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aragon_aragon-apps
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aragon_aragon-apps having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/manikandanraji_twitter-clone-frontend
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/manikandanraji_twitter-clone-frontend having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/functionless_functionless
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/functionless_functionless having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/stealthdrop_stealthdrop
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/stealthdrop_stealthdrop having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/apollographql_apollo-link-persisted-queries
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/apollographql_apollo-link-persisted-queries having 2 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Shopify_product-reviews-sample-app
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Shopify_product-reviews-sample-app having 4 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hiroppy_ssr-sample
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hiroppy_ssr-sample having 14 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Epistimio_orion
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Epistimio_orion having 53 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/stackrole_gatsby-starter-foundation
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/stackrole_gatsby-starter-foundation having 3 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/bandprotocol_bandchain
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/bandprotocol_bandchain having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/shoutem_extensions
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/shoutem_extensions having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/adieuadieu_retinal
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/adieuadieu_retinal having 2 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hasura_json2graphql
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hasura_json2graphql having 9 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nhn_toast-ui.vue-calendar
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nhn_toast-ui.vue-calendar having 2 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nervosnetwork_muta
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nervosnetwork_muta having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/tokopedia_treats
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/tokopedia_treats having 16 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hasura_client-side-graphql
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hasura_client-side-graphql having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Uniswap_org-v1
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Uniswap_org-v1 having 4 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/alytrics_yaba-social
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/alytrics_yaba-social having 23 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/4GeeksAcademy_Templates-Boilerplates
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/4GeeksAcademy_Templates-Boilerplates having 3 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/delucis_astro-netlify-cms
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/delucis_astro-netlify-cms having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SalesforceCommerceCloud_sfcc-sample-apps
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SalesforceCommerceCloud_sfcc-sample-apps having 2 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/katopz_react-apollo-graphql-github-example
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/katopz_react-apollo-graphql-github-example having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/grand-stack_graphql-auth-directives
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/grand-stack_graphql-auth-directives having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/docker-hy_docker-hy.github.io
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/docker-hy_docker-hy.github.io having 3 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/18F_handbook
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/18F_handbook having 21 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/0xHexE_keycloak-hasura-connector
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/0xHexE_keycloak-hasura-connector having 21 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#           {
#             products {
#               id
#               name
#             }
#           }
#         `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/gil--_gatsby-starter-shopify-app
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/gil--_gatsby-starter-shopify-app having 4 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/gil--_gatsby-starter-shopifypwa
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/gil--_gatsby-starter-shopifypwa having 4 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/infrastructure-components_infrastructure-components
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/infrastructure-components_infrastructure-components having 2 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/starknet-io_starknet-website
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/starknet-io_starknet-website having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DidoMarchet_starter-kit-nuxt-locomotive-scroll
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DidoMarchet_starter-kit-nuxt-locomotive-scroll having 54 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/System-Glitch_Solidity-IDE
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/System-Glitch_Solidity-IDE having 3 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Uniswap_api-deprecated
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Uniswap_api-deprecated having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-samples_aws-builders-fair-projects
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-samples_aws-builders-fair-projects having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/BuidlGuidl_abi.ninja
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/BuidlGuidl_abi.ninja having 73 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/realm_realm-graphql
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/realm_realm-graphql having 10 candidate files.
# Found 8 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/henry40408_awesome-stars
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/henry40408_awesome-stars having 1 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/strues_boldr
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/strues_boldr having 2 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/lumen-cms_lumen-cms
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/lumen-cms_lumen-cms having 4 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/denniske_aoe2companion
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/denniske_aoe2companion having 15 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Bayer-Group_ol-kit
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Bayer-Group_ol-kit having 306 candidate files.
# Found 3 gql strings in the repository.
# Found 1 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
# {
#   landpads {
#     location {
#       latitude
#       longitude
#       name
#       region
#     }
#     full_name
#     landing_type
#     attempted_landings
#   }
# }
# `'.
# Unable to extract operation type from GQL section 'gql`
# {
#   launchesPastResult {
#     data {
#       launch_site {
#         site_id
#         site_name_long
#         site_name
#       }
#       launch_date_utc
#     }
#   }
# }
# `'.
# Unable to extract operation type from GQL section 'gql`
# {
#   launchpads {
#     location {
#       latitude
#       longitude
#       name
#       region
#     }
#     name
#     successful_launches
#     vehicles_launched {
#       id
#       cost_per_launch
#     }
#     wikipedia
#     id
#     details
#   }
# }
# `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/monopayments_iban.im
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/monopayments_iban.im having 6 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/strapi_strapi-starter-angular-blog
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/strapi_strapi-starter-angular-blog having 1 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/javamonn_sunspot
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/javamonn_sunspot having 11 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/xilibi2003_training_camp_2
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/xilibi2003_training_camp_2 having 13 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/kubernetes-hy_kubernetes-hy.github.io
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/kubernetes-hy_kubernetes-hy.github.io having 6 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/m-rgba_hasura-django-starter
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/m-rgba_hasura-django-starter having 1 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/vgrafe_nextjs-auth0-hasura
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/vgrafe_nextjs-auth0-hasura having 19 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     user {
#       name
#     }
#   }
# `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hygraph_example_01_nextjs_apollo
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hygraph_example_01_nextjs_apollo having 1 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nerdify_db-schema-diagram
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nerdify_db-schema-diagram having 7 candidate files.
# Found 4 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SashenJayathilaka_Unique-Project-Ideas
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/SashenJayathilaka_Unique-Project-Ideas having 18 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/briancaffey_django-postgres-vue-gitlab-ecs
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/briancaffey_django-postgres-vue-gitlab-ecs having 5 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/gitcoinco_passport-sdk
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/gitcoinco_passport-sdk having 19 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/arkhn_pyrog
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/arkhn_pyrog having 12 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/rigelprotocol_SmartswapDappV2
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/rigelprotocol_SmartswapDappV2 having 126 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nikgraf_graphql-apollo-client-course
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nikgraf_graphql-apollo-client-course having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aerogear_datasync-voyager
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aerogear_datasync-voyager having 35 candidate files.
# Found 7 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`{
#       hello
#     }`'.
# Unable to extract operation type from GQL section 'gql`{
#         fails
#       }`'.
# Unable to extract operation type from GQL section 'gql`{
#       getUser(id:0){id,name,favoriteHorse{name,breed}}
#     }`'.
# Unable to extract operation type from GQL section 'gql`{
#       getUser(id:1){
#         id,
#         name,
#         favoriteHorse{name,breed},
#         friends{
#           id,
#           name,
#           favoriteHorse{name,breed}
#         }}
#     }`'.
# Unable to extract operation type from GQL section 'gql`{
#         doesNotExist
#       }`'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-amplify_amplify-codegen
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/aws-amplify_amplify-codegen having 5 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nhn_toast-ui.vue-chart
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/nhn_toast-ui.vue-chart having 4 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/launchscout_graphql-admin-react
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/launchscout_graphql-admin-react having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/usecannon_cannon
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/usecannon_cannon having 73 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/graphile_bootstrap-react-apollo
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/graphile_bootstrap-react-apollo having 1 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/AISHU-Technology_kweaver
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/AISHU-Technology_kweaver having 522 candidate files.
# Found 9 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
# //   query DataQuery($id: ID!, $class: String!, $q: String!, $page: Int = 1, $size: Int = 20, $query_all: Boolean!) {
# //     search_v(id: $id, class: $class, q: $q, page: $page, size: $size, query_all: $query_all) {
# //       time
# //       count
# //       vertexes {
# //         class
# //         color
# //         name
# //         id
# //         expand
# //         analysis
# //         hl
# //         alias
# //         properties {
# //           n
# //           v
# //           hl
# //         }
# //       }
# //     }
# //   }
# // `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/delegatable_MobyMask
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/delegatable_MobyMask having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/keystonejs_keystone-jamstack-plus
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/keystonejs_keystone-jamstack-plus having 8 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/abhi40308_instagram-clone
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/abhi40308_instagram-clone having 14 candidate files.
# Found 12 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     Post(order_by: { created_at: desc }) {
#       id
#     }
#   }
# `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/simarmannsingh_gatsby-netlifycms-modern-blog
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/simarmannsingh_gatsby-netlifycms-modern-blog having 2 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/republik_plattform
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/republik_plattform having 0 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/pangolindex_pangolin.exchange
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/pangolindex_pangolin.exchange having 10 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/contentful_template-marketing-webapp-nextjs
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/contentful_template-marketing-webapp-nextjs having 8 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/rossmc_how-to-venia
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/rossmc_how-to-venia having 5 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/udacity_live-codings-react-nanodegree
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/udacity_live-codings-react-nanodegree having 168 candidate files.
# Found 4 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/perpetual-protocol_perp-curie-arbitrageur
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/perpetual-protocol_perp-curie-arbitrageur having 1 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Shopify_shopify-marketplaces-buyer-app
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Shopify_shopify-marketplaces-buyer-app having 10 candidate files.
# Found 16 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   ${CORE_CART_FIELDS}
#   mutation cartLinesRemove($cartId: ID!, $lineIds: [ID!]!) {
#     cartLinesRemove(cartId: $cartId, lineIds: $lineIds) {
#       cart {
#         ...CoreCartFields
#       }
#       userErrors {
#         code
#         field
#         message
#       }
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${CORE_CART_FIELDS}
#   mutation cartLinesUpdate($cartId: ID!, $lines: [CartLineUpdateInput!]!) {
#     cartLinesUpdate(cartId: $cartId, lines: $lines) {
#       cart {
#         ...CoreCartFields
#       }
#       userErrors {
#         code
#         field
#         message
#       }
#     }
#   }
# `'.
# Unable to extract operation type from GQL section 'gql`
#     ${CORE_CART_FIELDS}
#     query getCart($id: ID!) {
#       cart(id: $id) {
#         ...CoreCartFields
#       }
#     }
#   `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/redochka_nextjs-shopify-app-no-custom-server
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/redochka_nextjs-shopify-app-no-custom-server having 19 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# ...
#   ${P.pagedCategories}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedTags}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedThreads}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedPosts}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedJobs}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedRepos}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedVideos}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedCategories}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.partialTags}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedThreads}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedPosts}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedJobs}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedRepos}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedVideos}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.community}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedThreads}
# `'.
# Unable to extract operation type from GQL section 'gql`
#   ${P.pagedUsers}
# `'.
# Unable to extract operation type from GQL section 'gql``'.
# Unable to extract operation type from GQL section 'gql``'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/kyma-project_console
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/kyma-project_console having 1216 candidate files.
# Found 184 gql strings in the repository.
# Found 8 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
# //   query Pod($namespace: String!) {
# //     pods(namespace: $namespace) {
# //       name
# //       labels
# //     }
# //   }
# // `'.
# Unable to extract operation type from GQL section 'gql`
# //   subscription Pod($namespace: String!) {
# //     podEvent(namespace: $namespace) {
# //       pod {
# //         name
# //         labels
# //       }
# //       type
# //     }
# //   }
# // `'.
# Unable to extract operation type from GQL section 'gql`${this.subscriptions}`'.
# Unable to extract operation type from GQL section 'gql`${query}`'.
# Unable to extract operation type from GQL section 'gql`${query}`'.
# Unable to extract operation type from GQL section 'gql`${query}`'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/openline-ai_openline-customer-os
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/openline-ai_openline-customer-os having 811 candidate files.
# Found 122 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/open-condo-software_condo
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/open-condo-software_condo having 2542 candidate files.
# Found 112 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/newjersey_navigator.business.nj.gov
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/newjersey_navigator.business.nj.gov having 1018 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/rage_ohjelmointi-20
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/rage_ohjelmointi-20 having 121 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     currentUser {
#       email
#       progress(course_id: "59314cb4-a9ca-43c9-b9a7-58c19325b44c") {
#         course {
#           id
#           name
#         }
#         user_course_progress {
#           id
#           progress
#         }
#         user_course_service_progresses {
#           id
#           progress
#           service {
#             id
#             name
#           }
#         }
#       }
#     }
#   }
# `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/pmbanugo_graphql-angular-intro
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/pmbanugo_graphql-angular-intro having 18 candidate files.
# Found 2 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#           {
#             books {
#               title
#               authors {
#                 name
#               }
#             }
#           }
#         `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/VitroidFPV_VitroidFPV
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/VitroidFPV_VitroidFPV having 28 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Zilliqa_devex
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Zilliqa_devex having 83 candidate files.
# Found 4 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/BlossomLabs_osmotic-funding
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/BlossomLabs_osmotic-funding having 61 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#     {
#       proposals(first: 25, orderBy: createdAt, orderDirection: desc) {
#         id
#         link
#         beneficiary {
#           id
#         }
#       }
#     }
#   `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/PrefectHQ_memory-graphql
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/PrefectHQ_memory-graphql having 16 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dan2dev_DefinitelyTyped
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dan2dev_DefinitelyTyped having 20591 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/holochain-open-dev_social-triangulation
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/holochain-open-dev_social-triangulation having 13 candidate files.
# Found 5 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#         {
#           me {
#             id
#             hasJoined
#           }
#           minVouches
#         }
#       `'.
# Unable to extract operation type from GQL section 'gql`
#   {
#     allAgents {
#       id
#       username
#       vouchesCount
#       isInitialMember
#     }
#   }
# `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Jarred-Sumner_yeet
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Jarred-Sumner_yeet having 401 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/PolymerLabs_project-health
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/PolymerLabs_project-health having 154 candidate files.
# Found 17 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`${queryToAdd}`'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DekodeInteraktiv_localwp-projectbase-addon
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/DekodeInteraktiv_localwp-projectbase-addon having 6 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/uq-its-ss_design-system
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/uq-its-ss_design-system having 94 candidate files.
# Found 0 gql strings in the repository.
# Found 1 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dukedaily_subgraph-demo-dapp
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dukedaily_subgraph-demo-dapp having 23 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/spokestack_node-spokestack
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/spokestack_node-spokestack having 58 candidate files.
# Found 4 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/amenabe22_chewata
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/amenabe22_chewata having 48 candidate files.
# Found 37 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#   {
#     latestNotifications {
#       id
#       notificationId
#       notificationType
#       message
#       user {
#         id
#         fullName
#         photo
#       }
#       target {
#         id
#         fullName
#       }
#       cover
#       createdAt
#       link
#     }
#   }
# `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Aakashdeveloper_july_react_eveng_22
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Aakashdeveloper_july_react_eveng_22 having 125 candidate files.
# Found 1 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/PabloSzx_graphql-tag-ts
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/PabloSzx_graphql-tag-ts having 3 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Troplo_Colubrina
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/Troplo_Colubrina having 86 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hacknlove_onGet
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/hacknlove_onGet having 165 candidate files.
# Found 3 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/meabed_gqlts
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/meabed_gqlts having 158 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/getflywheel_local-addon-backups
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/getflywheel_local-addon-backups having 67 candidate files.
# Found 15 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/lupas_vuetify-i18n-language-switcher-nuxt
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/lupas_vuetify-i18n-language-switcher-nuxt having 1 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/centrifuge_tinlake-ui
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/centrifuge_tinlake-ui having 115 candidate files.
# Found 3 gql strings in the repository.
# Found 0 constants in the repository.
# Unable to extract operation type from GQL section 'gql`
#           {
#             pools {
#               id
#               totalDebt
#               totalRepaysAggregatedAmount
#               ongoingLoans: loans(where: { opened_gt: 0, closed: null, debt_gt: 0 }) {
#                 id
#               }
#               weightedInterestRate
#               seniorInterestRate
#               version
#             }
#           }
#         `'.
# Unable to extract operation type from GQL section 'gql`
#         {
#           pools (where : {id: "${root}"}){
#             id
#             loans {
#               id
#               pool {
#                 id
#               }
#               index
#               owner
#               opened
#               closed
#               debt
#               interestRatePerSecond
#               ceiling
#               threshold
#               borrowsCount
#               borrowsAggregatedAmount
#               repaysCount
#               repaysAggregatedAmount
#               nftId
#               nftRegistry
#             }
#           }
#         }
#         `'.
# Unable to extract operation type from GQL section 'gql`
#         {
#           proxies (where: {owner:"${user}"})
#             {
#               id
#               owner
#             }
#           }
#         `'.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dferber90_lovely-webapp
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/dferber90_lovely-webapp having 107 candidate files.
# Found 7 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/netlify_netlify-dev-gatsby-fauna-demo
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/netlify_netlify-dev-gatsby-fauna-demo having 15 candidate files.
# Found 2 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/haticekatranci_one-click-hugo-cms
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/haticekatranci_one-click-hugo-cms having 13 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.
# Found repo dir /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/broxus_ever-wever
# Extracting query-name-pairs from repository /content/drive/MyDrive/asdl_project/dataset_generator/collected_repos/broxus_ever-wever having 29 candidate files.
# Found 0 gql strings in the repository.
# Found 0 constants in the repository.

# %%
# !python3 dataset_generator/combine_extracted_queries.py
# Out:
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/HappyDream0317_Microservices-GrowLabs.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Fernanda-Kipper_challenge-frontend.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Evavic44_rocketmeme.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/FormidableLabs_graphql-typescript-blog.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/FormidableLabs_seattlejsconf-app.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/HappyDream0317_impermax-x-uniswap-v2-interface.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/HappyDream0317_self-serve-mint.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/HausDAO_daohaus-web.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Laravel-VPN-Admin_api-core.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/IndexCoop_index-ui.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Meeovi_Collaborrate.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/0xTranqui_lostandfound-zora-marketplace.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/LFSCamargo_Chatify.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/ashutosh1919_masterPortfolio.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/withspectrum_spectrum.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/datopian_portaljs.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Canner_cannercms.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/42atomys_stud42.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/replicatedhq_kots.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/SaraVieira_awesome-talks.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/aerogear_offix.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/aws-samples_lambda-refarch-imagerecognition.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/saleor_saleor-storefront.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/AztecProtocol_aztec-v1.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/apollographql_reason-apollo.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/grand-stack_grand-stack-starter.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Shopify_shopify-demo-app-node-react.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/functionless_functionless.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/manikandanraji_twitter-clone-frontend.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/hiroppy_ssr-sample.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Shopify_product-reviews-sample-app.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/stealthdrop_stealthdrop.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/apollographql_apollo-link-persisted-queries.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/aragon_aragon-apps.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Epistimio_orion.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/stackrole_gatsby-starter-foundation.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/bandprotocol_bandchain.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/nhn_toast-ui.vue-calendar.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/adieuadieu_retinal.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/hasura_json2graphql.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/tokopedia_treats.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/shoutem_extensions.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/nervosnetwork_muta.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/hasura_client-side-graphql.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Uniswap_org-v1.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/alytrics_yaba-social.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/4GeeksAcademy_Templates-Boilerplates.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/katopz_react-apollo-graphql-github-example.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/SalesforceCommerceCloud_sfcc-sample-apps.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/docker-hy_docker-hy.github.io.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/delucis_astro-netlify-cms.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/grand-stack_graphql-auth-directives.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/18F_handbook.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/0xHexE_keycloak-hasura-connector.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/DidoMarchet_starter-kit-nuxt-locomotive-scroll.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/gil--_gatsby-starter-shopify-app.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/gil--_gatsby-starter-shopifypwa.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/infrastructure-components_infrastructure-components.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/starknet-io_starknet-website.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/System-Glitch_Solidity-IDE.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Uniswap_api-deprecated.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/aws-samples_aws-builders-fair-projects.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/realm_realm-graphql.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/strues_boldr.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/henry40408_awesome-stars.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/denniske_aoe2companion.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/lumen-cms_lumen-cms.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/BuidlGuidl_abi.ninja.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/monopayments_iban.im.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/javamonn_sunspot.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Bayer-Group_ol-kit.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/xilibi2003_training_camp_2.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries
yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/DoBestMan_spectrum.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/DanieleSalatti_gitcoin-grants-conviction.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/NoQuarterTeam_split.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Shopify_fulfillment-order-sample-app.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Open-NC_reentry-resources-hub.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Popcorn-moe_Web.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/SkyCaptainess_Shopify-nextjs.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Russell1130_decentral-staking.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Superdev0103_react-graph-demo.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Polygon-Academy_basicnfts.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Project-Gutenberg_nCovMemory-Web.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/RyanCCollins_ryancollinsio.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Vandivier_devfit.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/TopSpeed1017_spiritswap-frontend.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/WestpacGEL_GEL.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/WorkingFamilies_Spoke_legacy.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/SwissLife-OSS_Boost.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Vrishtrix_fullstack-ts-boilerplate.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Yash621_meta-meet.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/SwissLife-OSS_IdOps.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/VitorLuizC_dev-demands.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/UOA-CS732-SE750-Students-2022_project-group-magenta-mice.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/aaronksaunders_amplify-remix-todos-1.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/alibaba-archive_serverless.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/aerogear_graphql-testx.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/agiledev0115_meteor-boilerplate.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/aws-samples_aws-appsync-presence-api.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/atomist_cli.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/automatica-core_automatica.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/atomist_sdm-pack-aspect.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/aws-samples_realtime-slot-car-racing-with-aws-amplify-aws-iot-core-and-amazon-kinesis-video-streams.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/anirudhvs_pragyan-ctf-22.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/awslabs_amplify-graphql-seed-plugin.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/bcgov_digital.gov.bc.ca.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/bgoonz_React_Notes_V3.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/bhargavaparoksham_scaffold-eth-lens-starter-kit.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/bloxapp_awesome-ssv.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/brave_ads-ui.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/clean-commit_gatsby-starter-henlo.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/broxus_ton-dex.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/chainsauce-org_chainsauce.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/cid-harvard_growth-lab-app-front-end.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/collinsmuriuki_covid-19-monitor.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/contentful_the-example-app.graphql.js.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/councilofelders_numerbay.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/crewnew-git_sveltekit-hasura-docker.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/deliteser112_idie-device-rolls.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/danielwii_asuna-admin.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/d-513_npm-all-packages.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/deliteser112_meteor-boiler-plate-app.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/department-stockholm_apollo-component.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/devondragon_SpringShopifyAppFramework.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/dm-drogeriemarkt_lisa.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/dong-dohai_serverless-content-encoding.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/feedadoc_feedadoc.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/ericsdevblog_django-vue-starter-blog.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/getflywheel_local-addon-atlas.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/getflywheel_local-addon-image-optimizer.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/getflywheel_local-addon-xdebug-phpstorm.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/getflywheel_local-addon-boilerplate.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/getflywheel_local-addon-notes.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/h-REA_holo-rea-proto.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/hashicorp_learn-terraform-preview-environment.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/heyrict_cindy-realtime.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/hyd628_delegation-dao-demo.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/iTwin_viewer.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/imodeljs_itwin-viewer.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/imodeljs_frontend-sample-showcase.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/ictsc_ictsc-score-server.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/impactMarket_mobile-app.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/kalwalt_gatsby-starter-i18n-bulma.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/impactasaurus_app.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/kata-containers_www.katacontainers.io.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/launchscout_graphql-admin.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/lcfr-eth_FlashbotsBundlerUI.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/kyma-incubator_varkes.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/karimould_minimal-multi-language-gatsby-starter-netlify-cms.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/mahendrasaikumargandham_portfolio.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/libero_reviewer-submission.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/malgamves_GameOfCharts.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/mgx5kw_MistyDAO.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/licensebat_licensebat.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/mwhorse46_uoona.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/mrdulin_react-apollo-graphql-starter-kit.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/naji0329_test-nft-project.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/moonshotcollective_drecruit.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/mrdulin_apollo-graphql-tutorial.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/nguyentung9820_DEX.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/orbiting_publikator-frontend.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/ocftw_open-star-ter-village.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/newsguildny_nytimesguild.org.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/nativesintech_native-owned-businesses.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/p1ass_graphql-redis-realtime-chat.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/oumoussa98_leeters.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/perpetual-protocol_perp-maker.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/parity-asia_hackathon-2022-summer.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/phamhongphuc_uit.hotel.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/renproject_command-center.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/rage_ohjelmointi-19.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/reservoirprotocol_seaport-oracle.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/pixeljar_local-addon-xdebug-vscode.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/robertrouse_theographic-web.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/ruleslabs_interface.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/sazzer_pusher-mud.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/samarjaffal_wuptick-frontend.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/setsun_react-koa-universal.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/shafayeatsumit_rugged-multisig.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/skovy_graphql-blog-client.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/ssteiger_minimal-dao.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/stevenpslade_maas.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/sumit-mahajan_generative-nft-interface.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/terryyyz_CodeBaseFrontendReactjs.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/thestuntcoder_europratsya.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/thomaswangio_react-producthunt.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/treejer_web.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/tomrutgers_middleman-webpack-netlify-cms.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/tylim88_Create-Prisma-App.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/wednesday-solutions_react-graphql-ts-template.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/wani-hackase_wanictf21spring-writeup.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/uw-labs_flaggio.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/wslyvh_buidl-explorer.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/zapkub_cu-vivid-museum-wiki.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/marian2js_finsharing.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/ziggy6792_cdk-monorepo-example-backend.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/yinMrsir_typescript-admin.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/yamapyblack_CryptoFrontier.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/OtterClam_otter-frontend.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/michey85_apollo-qql-todos.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/aciura_Solidity-Marketplace-Dapp.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/atomist_uhura.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/austintgriffith_banana-auction.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/amclin_react-project-boilerplate.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/deliteser112_meteor-graphql-react-device.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/bedwarsify_bedwarsify-overlay.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/BlockedTODO_BlockedTODO.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/0xTranqui_lostandfound-optimism-marketplace.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/dtan4_ec2-event-slack-notifier.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/getflywheel_local-addon-instant-reload.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/snipcart_Strapi-Nuxt-Snipcart.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/stvkoch_graphqlizejs.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/ruoduan-hub_my-Gatsby-Blog.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/StarlingXWeb_starlingx-website.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/my-lambda-projects_Lambda.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/nhost_nhost.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/guidone_node-red-contrib-chatbot.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/OriginProtocol_origin.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/eea-oasis_baseline.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Ninjas-Code-official_Enatega-Restaurant-Solution.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/awslabs_aws-dataall.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Ninjas-Code-official_Marketplace-Food-Delivery-Solution.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/aws-amplify_amplify-category-api.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/chaoss_grimoirelab-sortinghat.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/dotansimha_graphql-code-generator-community.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/coderplanets_coderplanets_admin.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/kyma-project_console.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/openline-ai_openline-customer-os.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/open-condo-software_condo.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/newjersey_navigator.business.nj.gov.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/rage_ohjelmointi-20.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/pmbanugo_graphql-angular-intro.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/VitroidFPV_VitroidFPV.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Zilliqa_devex.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/BlossomLabs_osmotic-funding.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/PrefectHQ_memory-graphql.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/dan2dev_DefinitelyTyped.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/holochain-open-dev_social-triangulation.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Jarred-Sumner_yeet.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/PolymerLabs_project-health.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/DekodeInteraktiv_localwp-projectbase-addon.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/uq-its-ss_design-system.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/dukedaily_subgraph-demo-dapp.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/amenabe22_chewata.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/spokestack_node-spokestack.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Aakashdeveloper_july_react_eveng_22.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/PabloSzx_graphql-tag-ts.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/Troplo_Colubrina.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/hacknlove_onGet.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/meabed_gqlts.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/lupas_vuetify-i18n-language-switcher-nuxt.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/getflywheel_local-addon-backups.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/centrifuge_tinlake-ui.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/dferber90_lovely-webapp.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/netlify_netlify-dev-gatsby-fauna-demo.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/haticekatranci_one-click-hugo-cms.yaml
# Found query file /content/drive/MyDrive/asdl_project/dataset_generator/collected_queries/broxus_ever-wever.yaml

# %% [markdown]
# # Install dependencies

# %%
# !nvidia-smi
# Out:
# Fri Jul  7 20:07:45 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     8W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !export CUDA_HOME=/usr/local/cuda-10.1
# !git clone https://github.com/NVIDIA/apex
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./apex

# %%
# !pip install ipdb
# Out:
# Requirement already satisfied: ipdb in /usr/local/lib/python3.10/dist-packages (0.13.13)
# Requirement already satisfied: ipython>=7.31.1 in /usr/local/lib/python3.10/dist-packages (from ipdb) (7.34.0)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from ipdb) (2.0.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipdb) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (0.18.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.31.1->ipdb) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.31.1->ipdb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.31.1->ipdb) (0.2.6)

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.4 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
# !pip install transformers
# !pip install pytorch_lightning
# Out:
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 55.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.0.4-py3-none-any.whl (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.22.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.0.1+cu118)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.0.0-py3-none-any.whl (728 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.8/728.8 kB 50.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.6.3)
# Collecting lightning-utilities>=0.7.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (2.27.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (3.8.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch_lightning) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch_lightning) (16.0.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->pytorch_lightning) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pytorch_lightning) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.9.0 pytorch_lightning-2.0.4 torchmetrics-1.0.0

# %%
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.65.0)
# Requirement already satisfied: torch!=1.12.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.0.1+cu118)
# Collecting accelerate>=0.20.2 (from transformers[torch])
#   Downloading accelerate-0.20.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.2->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers[torch]) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[torch]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[torch]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[torch]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[torch]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.9->transformers[torch]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.9->transformers[torch]) (16.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.9->transformers[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.9->transformers[torch]) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.20.3

# %% [markdown]
# # Training Tutorial Code Part 1

# %%
import argparse
import glob
import os
import json
import time
import logging
import random
import re
import ipdb as pdb
from tqdm import tqdm
from itertools import chain
from string import punctuation
from transformers import T5Model, T5Tokenizer

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl


from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

set_seed(42)

# %%
logger = logging.getLogger(__name__)

class LoggingCallback(pl.Callback):
  def on_validation_end(self, trainer, pl_module):
    logger.info("***** Validation results *****")
    if pl_module.is_logger():
      metrics = trainer.callback_metrics
      # Log results
      for key in sorted(metrics):
        if key not in ["log", "progress_bar"]:
          logger.info("{} = {}\n".format(key, str(metrics[key])))

  def on_test_end(self, trainer, pl_module):
    logger.info("***** Test results *****")

    if pl_module.is_logger():
      metrics = trainer.callback_metrics

      # Log and save results to file
      output_test_results_file = os.path.join(pl_module.hparams.output_dir, "test_results.txt")
      with open(output_test_results_file, "w") as writer:
        for key in sorted(metrics):
          if key not in ["log", "progress_bar"]:
            logger.info("{} = {}\n".format(key, str(metrics[key])))
            writer.write("{} = {}\n".format(key, str(metrics[key])))

# %%
args_dict = dict(
    data_dir="", # path for data files
    output_dir="", # path to save the checkpoints
    model_name_or_path='t5-base',
    tokenizer_name_or_path='t5-base',
    max_seq_length=512,
    learning_rate=3e-4,
    weight_decay=0.0,
    adam_epsilon=1e-8,
    warmup_steps=0,
    train_batch_size=8,
    eval_batch_size=8,
    num_train_epochs=2,
    gradient_accumulation_steps=16,
    n_gpu=1,
    early_stop_callback=False,
    fp_16=False, # if you want to enable 16-bit training then install apex and set this to true
    opt_level='O1', # you can find out more on optimisation levels here https://nvidia.github.io/apex/amp.html#opt-levels-and-properties
    max_grad_norm=1.0, # if you enable 16-bit training then set this to a sensible value, 0.5 is a good default
    seed=42,
)

# %% [markdown]
# # Tutorial Dataset preparation

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -xvf aclImdb_v1.tar.gz
# Out:
# --2023-07-06 18:48:59--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# aclImdb_v1.tar.gz: Operation not supported
#
# Cannot write to ‘aclImdb_v1.tar.gz’ (Success).
# tar: aclImdb_v1.tar.gz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
train_pos_files = glob.glob('aclImdb/train/pos/*.txt')
train_neg_files = glob.glob('aclImdb/train/neg/*.txt')

# %%
len(train_pos_files), len(train_neg_files)
# Out:
# (12500, 12500)

# %%
# !mkdir aclImdb/val aclImdb/val/pos aclImdb/val/neg

# %%
random.shuffle(train_pos_files)
random.shuffle(train_neg_files)

val_pos_files = train_pos_files[:1000]
val_neg_files = train_neg_files[:1000]

# %%
import shutil

# %%
for f in val_pos_files:
  shutil.move(f,  'aclImdb/val/pos')
for f in val_neg_files:
  shutil.move(f,  'aclImdb/val/neg')

# %% [markdown]
# # Tutorial Code Part 2

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
# Out:
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:163: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
ids_neg = tokenizer.encode('negative </s>')
ids_pos = tokenizer.encode('positive </s>')
len(ids_neg), len(ids_pos)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:226: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# (2, 2)

# %%
# !pwd
os.chdir("/content/drive/MyDrive/finetune")
# !pwd
# Out:
# /content
# /content/drive/MyDrive/finetune

# %%
from torch.utils.data import Dataset

class ImdbDataset(Dataset):
  def __init__(self, tokenizer, data_dir, type_path,  max_len=512):
    self.pos_file_path = os.path.join(data_dir, type_path, 'pos')
    self.neg_file_path = os.path.join(data_dir, type_path, 'neg')

    self.pos_files = glob.glob("%s/*.txt" % self.pos_file_path)
    self.neg_files = glob.glob("%s/*.txt" % self.neg_file_path)
    print(str(self.pos_files))

    self.pos_files = self.pos_files[:100]
    self.neg_files = self.neg_files[:100]

    self.max_len = max_len
    self.tokenizer = tokenizer
    self.inputs = []
    self.targets = []

    self._build()

  def __len__(self):
    return len(self.inputs)

  def __getitem__(self, index):
    source_ids = self.inputs[index]["input_ids"].squeeze()
    target_ids = self.targets[index]["input_ids"].squeeze()

    src_mask    = self.inputs[index]["attention_mask"].squeeze()  # might need to squeeze
    target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

    return {"source_ids": source_ids, "source_mask": src_mask, "target_ids": target_ids, "target_mask": target_mask}

  def _build(self):
    self._buil_examples_from_files(self.pos_files, 'positive')
    self._buil_examples_from_files(self.neg_files, 'negative')

  def _buil_examples_from_files(self, files, sentiment):
    REPLACE_NO_SPACE = re.compile("[.;:!\'?,\"()\[\]]")
    REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")

    for path in tqdm(files):
      with open(path, 'r') as f:
        text = f.read()

      line = text.strip()
      line = REPLACE_NO_SPACE.sub("", line)
      line = REPLACE_WITH_SPACE.sub("", line)
      line = line + ' </s>'

      target = sentiment + " </s>"

      # todo: add query name to tokenized input  and have separator inbetween
       # tokenize inputs
      tokenized_inputs = self.tokenizer.batch_encode_plus(
          [line], max_length=self.max_len, pad_to_max_length=True, return_tensors="pt"
      )
       # tokenize targets
      tokenized_targets = self.tokenizer.batch_encode_plus(
          [target], max_length=2, pad_to_max_length=True, return_tensors="pt"
      )

      self.inputs.append(tokenized_inputs)
      self.targets.append(tokenized_targets)

# %%
dataset = ImdbDataset(tokenizer, 'aclImdb', 'val',  max_len=512)
len(dataset)
# Out:
# ['aclImdb/val/pos/1400_7.txt', 'aclImdb/val/pos/2228_7.txt', 'aclImdb/val/pos/1889_10.txt', 'aclImdb/val/pos/3580_10.txt', 'aclImdb/val/pos/3356_10.txt', 'aclImdb/val/pos/4399_9.txt', 'aclImdb/val/pos/5192_7.txt', 'aclImdb/val/pos/5851_10.txt', 'aclImdb/val/pos/6020_7.txt', 'aclImdb/val/pos/7367_7.txt', 'aclImdb/val/pos/7254_10.txt', 'aclImdb/val/pos/7632_10.txt', 'aclImdb/val/pos/7836_8.txt', 'aclImdb/val/pos/8668_9.txt', 'aclImdb/val/pos/9082_10.txt', 'aclImdb/val/pos/9047_10.txt', 'aclImdb/val/pos/9019_8.txt', 'aclImdb/val/pos/9227_9.txt', 'aclImdb/val/pos/9407_8.txt', 'aclImdb/val/pos/9989_9.txt', 'aclImdb/val/pos/12166_10.txt', 'aclImdb/val/pos/695_10.txt', 'aclImdb/val/pos/96_10.txt', 'aclImdb/val/pos/76_7.txt', 'aclImdb/val/pos/72_7.txt', 'aclImdb/val/pos/66_8.txt', 'aclImdb/val/pos/64_7.txt', 'aclImdb/val/pos/63_10.txt', 'aclImdb/val/pos/49_10.txt', 'aclImdb/val/pos/45_10.txt', 'aclImdb/val/pos/25_7.txt', 'aclImdb/val/pos/0_9.txt', 'aclImdb/val/pos/243_10.txt', 'aclImdb/val/pos/242_8.txt', 'aclImdb/val/pos/235_10.txt', 'aclImdb/val/pos/228_7.txt', 'aclImdb/val/pos/224_10.txt', 'aclImdb/val/pos/222_10.txt', 'aclImdb/val/pos/193_7.txt', 'aclImdb/val/pos/174_7.txt', 'aclImdb/val/pos/172_10.txt', 'aclImdb/val/pos/162_8.txt', 'aclImdb/val/pos/151_10.txt', 'aclImdb/val/pos/141_9.txt', 'aclImdb/val/pos/139_10.txt', 'aclImdb/val/pos/133_10.txt', 'aclImdb/val/pos/369_10.txt', 'aclImdb/val/pos/342_10.txt', 'aclImdb/val/pos/334_10.txt', 'aclImdb/val/pos/321_10.txt', 'aclImdb/val/pos/310_7.txt', 'aclImdb/val/pos/301_10.txt', 'aclImdb/val/pos/276_10.txt', 'aclImdb/val/pos/268_8.txt', 'aclImdb/val/pos/257_7.txt', 'aclImdb/val/pos/506_7.txt', 'aclImdb/val/pos/500_9.txt', 'aclImdb/
[00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2377: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 100%|██████████| 100/100 [00:16<00:00,  5.95it/s]
# 100%|██████████| 100/100 [01:06<00:00,  1.51it/s]
# 200

# %%
data = dataset[28]
print(tokenizer.decode(data['source_ids']))
print(tokenizer.decode(data['target_ids']))
# Out:
# If you get it its magnificentIf you dont its decentPlease understand that getting it does not necessarily mean youve gone through a school shooting There is so much more to this movie that at times the school shooting becomes insignificantAbove all its a movie about acceptance both superficiallyof a traumatic event but also of people who are different for whatever reasonIts also a movie about unendurable pain and how different people endure it In this case the contrast between Alicias rage and Deannas obsession creates an atmosphere of such palpable anxiety that halfway through the movie we wonder how the director could possibly pull a happy ending out of his hat Thankfully the audience is given credit for being human beings our intelligence is not insulted by a sappy implausibly moralistic endingAbove and beyond that I try to keep a clear head about movies being fiction and all that Yet I must admit I cried like a lost little baby during this movie There were certain things about it that hit *very* close to home and opened up some old wounds that never quite healed But that is not necessarily a bad thing</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# positive</s>

# %%
# !mkdir -p t5_imdb_sentiment

# %%
args_dict.update({'data_dir': 'aclImdb', 'output_dir': 't5_imdb_sentiment', 'num_train_epochs':2})
args = argparse.Namespace(**args_dict)

checkpoint_callback = pl.callbacks.ModelCheckpoint(
    dirpath=args.output_dir, filename="checkpoint", monitor="val_loss", mode="min", save_top_k=5
)

train_params = dict(
    accumulate_grad_batches=args.gradient_accumulation_steps,
    accelerator='gpu',
    #devices=1,
    #gpus=args.n_gpu,
    max_epochs=args.num_train_epochs,
    #early_stop_callback=False,
    precision= 16 if args.fp_16 else 32,
    #amp_level=args.opt_level,
    gradient_clip_val=args.max_grad_norm,
    callbacks=[LoggingCallback(),checkpoint_callback],
)

# %%
def get_dataset(tokenizer, type_path, args):
  return ImdbDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)

# %%
class T5FineTuner(pl.LightningModule):
  def __init__(self, hparams):
    super(T5FineTuner, self).__init__()
    self.save_hyperparameters(hparams)
    self.training_step_outputs = []
    self.validation_step_outputs = []
    #self.automatic_optimization=False
    # pdb.set_trace()
    self.model = T5ForConditionalGeneration.from_pretrained(hparams.model_name_or_path)
    self.tokenizer = T5Tokenizer.from_pretrained(hparams.tokenizer_name_or_path)

  def is_logger(self):
    return self.trainer.global_rank <= 0

  def forward(
      self, input_ids, attention_mask=None, decoder_input_ids=None, decoder_attention_mask=None, labels=None
  ):
    return self.model(
        input_ids,
        attention_mask=attention_mask,
        decoder_input_ids=decoder_input_ids,
        decoder_attention_mask=decoder_attention_mask,
        labels=labels,
    )

  def _step(self, batch):
    labels = batch["target_ids"]
    labels[labels[:, :] == self.tokenizer.pad_token_id] = -100
    outputs = self(
        input_ids=batch["source_ids"],
        attention_mask=batch["source_mask"],
        labels=labels,
        decoder_attention_mask=batch['target_mask']
    )

    loss = outputs[0]

    return loss

  def training_step(self, batch, batch_idx):
    loss = self._step(batch)
    self.training_step_outputs.append(loss)


    #tensorboard_logs = {"train_loss": loss}
    return {"loss": loss}

  def on_train_epoch_end(self):
    epoch_average = torch.stack(self.training_step_outputs).mean()
    #avg_train_loss = torch.stack([x["loss"] for x in outputs]).mean()
    #tensorboard_logs = {"avg_train_loss": epoch_average}
    self.log("training_epoch_average", epoch_average)
    self.training_step_outputs.clear()  # free memory
    return {"avg_train_loss": epoch_average}

  def validation_step(self, batch, batch_idx):
    loss = self._step(batch)
    self.validation_step_outputs.append(loss)
    return {"val_loss": loss}

  def on_validation_epoch_end(self):
    epoch_average = torch.stack(self.validation_step_outputs).mean()
    # avg_loss = torch.stack([x["val_loss"] for x in outputs]).mean()
    self.log("val_loss", epoch_average)
    self.validation_step_outputs.clear()  # free memory
    #tensorboard_logs = {"val_loss": avg_loss}
    return {"val_loss": epoch_average}

  def configure_optimizers(self):
    "Prepare optimizer and schedule (linear warmup and decay)"

    model = self.model
    no_decay = ["bias", "LayerNorm.weight"]
    optimizer_grouped_parameters = [
        {
            "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
            "weight_decay": self.hparams.weight_decay,
        },
        {
            "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
            "weight_decay": 0.0,
        },
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=self.hparams.learning_rate, eps=self.hparams.adam_epsilon)
    self.opt = optimizer
    return [optimizer]

  #def optimizer_step(self, epoch, batch_idx, optimizer, optimizer_idx, second_order_closure=None):
  #  optimizer.step()
  #  optimizer.zero_grad()
  #  self.lr_scheduler.step()

  def get_tqdm_dict(self):
    tqdm_dict = {"loss": "{:.3f}".format(self.trainer.avg_loss), "lr": self.lr_scheduler.get_last_lr()[-1]}

    return tqdm_dict

  def train_dataloader(self):
    print('loadingtrain data')
    train_dataset = get_dataset(tokenizer=self.tokenizer, type_path="train", args=self.hparams)
    dataloader = DataLoader(train_dataset, batch_size=self.hparams.train_batch_size, drop_last=True, shuffle=True, num_workers=4)
    t_total = (
        (len(dataloader.dataset) // (self.hparams.train_batch_size * max(1, self.hparams.n_gpu)))
        // self.hparams.gradient_accumulation_steps
        * float(self.hparams.num_train_epochs)
    )
    scheduler = get_linear_schedule_with_warmup(
        self.opt, num_warmup_steps=self.hparams.warmup_steps, num_training_steps=t_total
    )
    self.lr_scheduler = scheduler
    return dataloader

  def val_dataloader(self):
    print('loading val data')
    val_dataset = get_dataset(tokenizer=self.tokenizer, type_path="val", args=self.hparams)
    return DataLoader(val_dataset, batch_size=self.hparams.eval_batch_size, num_workers=4)

# %% [markdown]
# # Debugging

# %%
model = T5FineTuner(args)
# Out:
# Downloading model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
train_params["precision"]='16-mixed'

# %%
train_params
# Out:
# {'accumulate_grad_batches': 16,
#  'accelerator': 'gpu',
#  'max_epochs': 2,
#  'precision': '16-mixed',
#  'gradient_clip_val': 1.0,
#  'callbacks': [<__main__.LoggingCallback at 0x7fc2e54d5330>,
#   <pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint at 0x7fc2e5521a50>]}

# %%
torch.cuda.get_device_name()
# Out:
# 'Tesla T4'

# %%
#train_params['callbacks'].pop(2)
#train_params

# %%
trainer = pl.Trainer(**train_params)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %%
trainer.fit(model)
# Out:
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 222 M
# -----------------------------------------------------
# 222 M     Trainable params
# 0         Non-trainable params
# 222 M     Total params
# 891.614   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
.txt', 'aclImdb/train/pos/11526_10.txt', 'aclImdb/train/pos/11795_10.txt', 'aclImdb/train/pos/11636_8.txt', 'aclImdb/train/pos/11444_10.txt', 'aclImdb/train/pos/11601_8.txt', 'aclImdb/train/pos/11347_10.txt', 'aclImdb/train/pos/11365_9.txt', 'aclImdb/train/pos/11706_10.txt', 'aclImdb/train/pos/11791_8.txt', 'aclImdb/train/pos/11656_9.txt', 'aclImdb/train/pos/11723_7.txt', 'aclImdb/train/pos/11745_10.txt', 'aclImdb/train/pos/11607_10.txt', 'aclImdb/train/pos/11389_7.txt', 'aclImdb/train/pos/11360_7.txt', 'aclImdb/train/pos/11753_10.txt', 'aclImdb/train/pos/11724_8.txt', 'aclImdb/train/pos/11391_8.txt', 'aclImdb/train/pos/11374_9.txt', 'aclImdb/train/pos/11788_8.txt', 'aclImdb/train/pos/11584_8.txt', 'aclImdb/train/pos/11796_9.txt', 'aclImdb/train/pos/11696_7.txt', 'aclImdb/train/pos/11766_8.txt', 'aclImdb/train/pos/11649_10.txt', 'aclImdb/train/pos/11629_10.txt', 'aclImdb/train/pos/11525_8.txt', 'aclImdb/train/pos/11694_7.txt', 'aclImdb/train/pos/11712_10.txt', 'aclImdb/train/pos/11480_10.txt', 'aclImdb/train/pos/11560_9.txt', 'aclImdb/train/pos/11675_10.txt', 'aclImdb/train/pos/11403_9.txt', 'aclImdb/train/pos/11432_9.txt', 'aclImdb/train/pos/11431_10.txt', 'aclImdb/train/pos/11695_9.txt', 'aclImdb/train/pos/11609 ...
# 100%|██████████| 100/100 [00:55<00:00,  1.79it/s]
# 100%|██████████| 100/100 [01:09<00:00,  1.44it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:280: PossibleUserWarning: The number of training batches (25) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=2` reached.

# %%
# !nvidia-smi
# Out:
# Fri Jul  7 20:20:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P0    34W /  70W |    153MiB / 15360MiB |     98%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
 # !mkdir t5_base_imdb_sentiment
# Out:
# mkdir: cannot create directory ‘t5_base_imdb_sentiment’: File exists

# %%
## save the model this way so next time you can load it using T5ForConditionalGeneration.from_pretrained
model.model.save_pretrained('t5_base_imdb_sentiment')

# %%
# !cd /content/drive/MyDrive/finetune/

# %% [markdown]
# # Eval

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

# %%
dataset = ImdbDataset(tokenizer, 'aclImdb', 'test',  max_len=512)
loader = DataLoader(dataset, batch_size=32, shuffle=True)
# Out:
# ['aclImdb/test/pos/11353_10.txt', 'aclImdb/test/pos/11696_10.txt', 'aclImdb/test/pos/11395_10.txt', 'aclImdb/test/pos/11490_10.txt', 'aclImdb/test/pos/11716_10.txt', 'aclImdb/test/pos/11618_10.txt', 'aclImdb/test/pos/11557_7.txt', 'aclImdb/test/pos/11734_10.txt', 'aclImdb/test/pos/11411_8.txt', 'aclImdb/test/pos/11630_7.txt', 'aclImdb/test/pos/11605_7.txt', 'aclImdb/test/pos/11638_10.txt', 'aclImdb/test/pos/11574_10.txt', 'aclImdb/test/pos/11511_10.txt', 'aclImdb/test/pos/11453_7.txt', 'aclImdb/test/pos/11527_10.txt', '
clImdb/test/pos/11670_7.txt', 'aclImdb/test/pos/11507_10.txt', 'aclImdb/test/pos/11406_8.txt', 'aclImdb/test/pos/11381_10.txt', 'aclImdb/test/pos/11728_7.txt', 'aclImdb/test/pos/11549_10.txt', 'aclImdb/test/pos/11393_10.txt', 'aclImdb/test/pos/11491_10.txt', 'aclImdb/test/pos/11598_10.txt', 'aclImdb/test/pos/11479_8.txt', 'aclImdb/test/pos/11396_10.txt', 'aclImdb/test/pos/11585_7.txt', 'aclImdb/test/pos/11647_10.txt', 'aclImdb/test/pos/11624_10.txt', 'aclImdb/test/pos/11422_7.txt', 'aclImdb/test/pos/11383_10.txt', 'aclImdb/test/pos/11646_8.txt', 'aclImdb/test/pos/11704_10.txt', 'aclImdb/test/pos/11404_8.txt', 'aclImdb/test/pos/11363_10.txt', 'aclImdb/test/pos/11658_8.txt', 'aclImdb/test/pos/11594_9.txt', 'aclImdb/test/pos/11433_7.txt', 'aclImdb/test/pos/11586_9.txt', 'aclImdb/test/pos/11648_10.txt', 'aclImdb/test/pos/11629_10.txt', 'aclImdb/test/pos/11713_9.txt', 'aclImdb/test/pos/11469_8.txt', 'aclImdb/test/pos/11576_10.txt', 'aclImdb/test/pos/11660_10.txt', 'aclImdb/test/pos/11559_9.txt', 'aclImdb/test/pos/11692_9.txt', 'aclImdb/test/pos/11601_9.txt', 'acl ...
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
it = iter(loader)
batch = next(it)
batch["source_ids"].shape
model.model.to('cuda')
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=32128, bias=False)
# )

# %%
outs = model.model.generate(input_ids=batch['source_ids'].cuda(),
                              attention_mask=batch['source_mask'].cuda(),
                              max_length=2)

dec = [tokenizer.decode(ids) for ids in outs]

texts = [tokenizer.decode(ids) for ids in batch['source_ids']]
targets = [tokenizer.decode(ids) for ids in batch['target_ids']]

# %%
for i in range(32):
    lines = textwrap.wrap("Review:\n%s\n" % texts[i], width=100)
    print("\n".join(lines))
    print("\nActual sentiment: %s" % targets[i])
    print("Predicted sentiment: %s" % dec[i])
    print("=====================================================================\n")
# Out:
# Review: I smiled through the whole film The music is great The storytelling is great Its a wonderful
# film This picture is made with respect and a true love of the sixties</s><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>
# =====================================================================
#
# Review: There are so very few films where just the title tells you all you need to know about the
# film Such a film is I Was A Communist For The FBI Another example would be I Married A Monster From
# Outer SpaceThe really interesting thing about this film is how in heavens name did this get
# nominated for an Oscar in the documentary category It is not a documentary in any sense of the word
# its not even in that hybrid category of docudrama Its just a rather exploitive film about the work
# of an FBI undercover agent named Matt Cvetic who infiltrated the Communist Party in Pittsburgh and
# got active in trying to take over the Steelworkers Union for the Communists and reporting on said
# activities to his handlers in the FBIA documentary of that work might have been interesting but what
# we got was a film to fit those paranoid times I found it fascinating that when Cvetic finally broke
# his cover it was to the House UnAmerican Activities Committee rather than the trial in New York of
# the Communist Party leaders There was a moment in the film where head Communist James Millican tells
# his followers to start spreading the word that the House Un American Activities Committee was
# composed of a bunch of right wing yahoos looking to get their names in front of the camera Now what
# could have given him that idea Anyway just connect the dots and no doubt the word their came from J
# Edgar Hoover trying to give some credence to HUAC by having an effective undercover come out there
# rather than at an actual trial Little thing there called cross examinationWarner Brothers who
# produced I Was A Communist For The FBI later produced Big Jim McLain which starred John Wayne about
# a HUAC investigator in Hawaii HUAC did grab on to credit for the work done by the Honolulu PD in
# breaking up a Communist spy ring there among the dockworkers But at least in John Waynes film nobody
# claimed it was a documentaryFrank Lovejoy is in the title role as Cvetic and his FBI handlers are
# Richard Webb and Philip Carey Dorothy Hart plays a Pittsburgh school teacher who says that there are
# 30 or so like here in that school system indoctrinating the young among whom is Ron Hagerthy
# Lovejoys son She has a change of heart about the Communists and Lovejoy has to save her from a
# homicidal fate planned by</s>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>
# =====================================================================
#
# Review: Sharkys Machine is easily one of Burt Reynolds best efforts It also stands as one of the
# best contemporary crime dramas Erotic and violent the movie distinguishes itself by setting the
# story in Atlanta and delivering a chaotic detective case to youthe viewer on a silver platter
# Dedicated and determined Sharky must stop the murder of Dominoe a lovely lady of the night whos
# clientel is anything but ordinary Before long Sharkys crimefighting Machine uncovers a conspiracy of
# the highest order which threatens to corrupt the inner body of Atlanta As a resident of Metro
# Atlanta I recall the excitement in town during the movies production Sharkys Machine goes to great
# lengths to give an accurate portrayal of Atlanta Twenty years removed and 2000000more people later
# the film stands the test of time Trust me Atlanta has not changed One of the highlights of the
# picture is Dar Robinsons daring stunta classic symbolic ending It was even featured on Thats
# Incredible ABCs reality show of the period Its just too bad that Hollywood does not make enough
# films like this one Kick back each your popcorn and watch sterling silver cinema action</s><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: I love this young people trapped in a house of horrors movie Not just because Im a huge
# Linnea QuigleyJill Terashita fan but because it is a lot of fun and actually scary at timesThe
# special effects are awesome especially Linneas scene with the lipstick and towards the end when
# almost everyone is dead and possessedPlenty of nudity provided by Linnea and Jill plenty of humor
# cool soundtrack high body count etcBy the way if you have never seen this one try and buywatch the
# Unrated version which has more gore and some scenes the rated version is missing</s><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>
# =====================================================================
#
# Review: I havent laughed this much in a long time or seen a film so ineptly made Talk about so bad
# it made me laughFirstly I estimate that for about 40 percent of the films length I couldnt tell what
# was happening or indeed even what I was seeing I can only describe the camera work as frenetic meets
# LSD There are whole segments minutes long where all you can see are blurred flashes and fragments of
# cave wall people and various other unidentifiable stuff I spent half the film asking my teenage
# daughters what was happening but they couldnt follow it any better than meThen there are the black
# moments when in an effort to scare us woooooooo everyones lights go out and the screen turns pitch
# black and I dont just mean for a few seconds I think the longest lasted almost two minutes I guess
# blank film is one way to keep costs downI suspect the director had recently read a book on all the
# mustdos to make a scary movie and decided to throw them all in about 20 times eachThere are three
# good things about this film 1 Its short at 90 minutes though still an hour and a half too long 2 All
# the characters die after all its impossible to care about any of them 3 There was one genuinely good
# scene when the group are looking up the shaft they came down after discovering their rope fallen to
# the bottom saw THAT coming a large boulder is pushed across the opening sealing them in I WASNT
# expecting that and it was genuinely chillingAnd whats with the early campfire scenes with the shot
# after shot after shot panning from behind the camp lights I swear the director used almost the same
# shot about 20 times in 5 minutesAnd Im positive that after the first kill the EXACT same footage of
# blood on the cave floor is used twice in about 90 secondsAll in all a CRAP piece of film making Ill
# watch almost anything but this is close to where Id draw the line</s><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review
s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: What has Rajiv Rai done to himself Once a hit director of films like Tridev and Vishwatama
# is now making one bad film after another I was initially excited at the thought of Rajiv Rai
# returning to the action genre but that soon fizzled out As a Rajiv Rai fan I thought I should at
# least give it a go but I left after an hour One reason for me leaving the film so early so the
# amount of Paki bashing in the film this was not in Rais previous ventureA lot of directors have
# tried Paki bashing but I did not expect it from Rajiv Rai Another letdown was the music Rajiv Rais
# have always had good music until now There is only one good song and that is Tere dekh dekh Ladgayan
# The performances are not upto scratch not even from Rai Loyalist NaseerUddin Shah Avoidable fare
# from once my favourite director</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: negative</s>
# Predicted sentiment: <pad>negative
# =====================================================================
#
# Review: I rented Boogie Nights last week and I could tell you when I watched the film I had a blast
# If you think that when you watch the film you will get sicked by the porn I mean yes if your not a
# porn person who cant bother being by it than this isnt the film to see But the thing is the whole
# film isnt really about porn Well halfway through the film is about the porn industry but the other
# half is about the character development and the bad situations these characters go through The
# actors played there roles perfect especially Mark Wahlberg John C Reilly and William H Macy The sex
# scenes of course are terrific but mainly focus on the characters hype in porn films until there
# struggles Excellent film one of the best Hedeens Outlook 1010 **** A+</s><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>positive
# =====================================================================
#
# Review: When i watch this movie i too get excited when seen bed scenes of miss world She has
# beautiful and charming body When cute lady do bed scenes and show her fully nude body i think male
# have hard to resisti think its time for cute girls like hrishita bhatt also do nude scenes At least
# no one wants to c nude body of ugly women like Seema biswas to c in bandit queenI concur with what
# mallickab has said The movie is portrayed in a way which appears to be a kind of vilification on the
# original content Emotions arent conveyed properly I guess a couple of notsogood performances also
# contributed to its mediocrity In my view Tabu would have been a much better choice for such a role
# instead of Aishwarya Rai In some of her scenes she looks a bit lusty which is not ultimately what
# the movie should have portrayed I also noticed a bit of overacting in some of her scenes Im a bitter
# critic of Aishwarya Rai Cant help it sorry for that Raincoat was a good movie by Rituparno Ghosh And
# I saw Choker Bali after seeing Raincoat I was not at all impressed</s><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual sentiment: positive</s>
# Predicted sentiment: <pad>negative
# =====================================================================

# %% [markdown]
# # GraphQl Model
#
# ---

# %%
# !pwd
os.chdir("/content/drive/MyDrive/finetune")
# !pwd
# Out:
# /content
# /content/drive/MyDrive/finetune

# %%
import os
from pathlib import Path
import argparse
import glob
import json
import time
import logging
import random
import re
import ipdb as pdb
from tqdm import tqdm
from itertools import chain
from string import punctuation
from transformers import T5Model, T5Tokenizer
import nltk

nltk.download('punkt')

from nltk.tokenize import sent_tokenize
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl

from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)

logger = logging.getLogger(__name__)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


class LoggingCallback(pl.Callback):
    def on_validation_end(self, trainer, pl_module):
        logger.info("***** Validation results *****")
        if pl_module.is_logger():
            metrics = trainer.callback_metrics
            # Log results
            for key in sorted(metrics):
                if key not in ["log", "progress_bar"]:
                    logger.info("{} = {}\n".format(key, str(metrics[key])))

    def on_test_end(self, trainer, pl_module):
        logger.info("***** Test results *****")

        if pl_module.is_logger():
            metrics = trainer.callback_metrics

            # Log and save results to file
            output_test_results_file = os.path.join(pl_module.hparams.output_dir, "test_results.txt")
            with open(output_test_results_file, "w") as writer:
                for key in sorted(metrics):
                    if key not in ["log", "progress_bar"]:
                        logger.info("{} = {}\n".format(key, str(metrics[key])))
                        writer.write("{} = {}\n".format(key, str(metrics[key])))


class GraphQlDataset(Dataset):
    def __init__(self, tokenizer, data_dir, type_path, max_len=512):
        self.pos_file_path = os.path.join(data_dir, 'dataset_' + type_path + "_pos.json")
        self.neg_file_path = os.path.join(data_dir, 'dataset_' + type_path + "_neg.json")

        self.max_len = max_len
        self.tokenizer = tokenizer
        self.inputs = []
        self.targets = []

        self._build()

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, index):
        source_ids = self.inputs[index]["input_ids"].squeeze()
        target_ids = self.targets[index]["input_ids"].squeeze()

        src_mask = self.inputs[index]["attention_mask"].squeeze()  # might need to squeeze
        target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

        return {"source_ids": source_ids, "source_mask": src_mask, "target_ids": target_ids, "target_mask": target_mask}

    def _build(self):
        self._build_examples_from_files(self.pos_file_path, 'consistent')
        self._build_examples_from_files(self.neg_file_path, 'inconsistent')

    def _build_examples_from_files(self, file_path, consistency):
        with open(file_path, 'r') as reader:
            dataset = json.load(reader)

        REPLACE_NO_SPACE = re.compile("[.;:!\'?,\"()\[\]]")
        REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")

        for data_entry in tqdm(dataset):
            content = data_entry["content"].strip()
            name = data_entry["name"].strip()

            line = content + ' </s>' + name
            line = REPLACE_NO_SPACE.sub("", line)
            line = REPLACE_WITH_SPACE.sub("", line)
            line = line + ' </s>'

            target = consistency + " </s>"

            # tokenize inputs
            tokenized_inputs = self.tokenizer.batch_encode_plus(
                [line], max_length=self.max_len, pad_to_max_length=True, return_tensors="pt"
            )
            # tokenize targets
            tokenized_targets = self.tokenizer.batch_encode_plus(
                [target], max_length=2, pad_to_max_length=True, return_tensors="pt"
            )

            self.inputs.append(tokenized_inputs)
            self.targets.append(tokenized_targets)

def get_dataset(tokenizer, type_path, args):
  return GraphQlDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)


class T5FineTuner(pl.LightningModule):
    def __init__(self, hparams):
        super(T5FineTuner, self).__init__()
        self.save_hyperparameters(hparams)
        self.training_step_outputs = []
        self.validation_step_outputs = []
        # pdb.set_trace()
        self.model = T5ForConditionalGeneration.from_pretrained(hparams.model_name_or_path)
        self.tokenizer = T5Tokenizer.from_pretrained(hparams.tokenizer_name_or_path)

    def is_logger(self):
        return self.trainer.global_rank <= 0

    def forward(
            self, input_ids, attention_mask=None, decoder_input_ids=None, decoder_attention_mask=None, labels=None
    ):
        return self.model(
            input_ids,
            attention_mask=attention_mask,
            decoder_input_ids=decoder_input_ids,
            decoder_attention_mask=decoder_attention_mask,
            labels=labels,
        )

    def _step(self, batch):
        labels = batch["target_ids"]
        labels[labels[:, :] == self.tokenizer.pad_token_id] = -100
        outputs = self(
            input_ids=batch["source_ids"],
            attention_mask=batch["source_mask"],
            labels=labels,
            decoder_attention_mask=batch['target_mask']
        )

        loss = outputs[0]

        return loss

    def training_step(self, batch, batch_idx):
        loss = self._step(batch)
        self.training_step_outputs.append(loss)
        return {"loss": loss}

    def on_train_epoch_end(self):
        epoch_average = torch.stack(self.training_step_outputs).mean()
        self.log("training_epoch_average", epoch_average)
        self.training_step_outputs.clear()  # free memory
        return {"avg_train_loss": epoch_average}

    def validation_step(self, batch, batch_idx):
        loss = self._step(batch)
        self.validation_step_outputs.append(loss)
        return {"val_loss": loss}

    def on_validation_epoch_end(self):
        epoch_average = torch.stack(self.validation_step_outputs).mean()
        self.log("val_loss", epoch_average)
        self.validation_step_outputs.clear()  # free memory
        return {"val_loss": epoch_average}

    def configure_optimizers(self):
        """Prepare optimizer and schedule (linear warmup and decay)"""

        model = self.model
        no_decay = ["bias", "LayerNorm.weight"]
        optimizer_grouped_parameters = [
            {
                "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
                "weight_decay": self.hparams.weight_decay,
            },
            {
                "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
                "weight_decay": 0.0,
            },
        ]
        optimizer = AdamW(optimizer_grouped_parameters, lr=self.hparams.learning_rate, eps=self.hparams.adam_epsilon)
        self.opt = optimizer
        return [optimizer]

    def get_tqdm_dict(self):
        tqdm_dict = {"loss": "{:.3f}".format(self.trainer.avg_loss), "lr": self.lr_scheduler.get_last_lr()[-1]}

        return tqdm_dict

    def train_dataloader(self):
        print('loadingtrain data')
        train_dataset = get_dataset(tokenizer=self.tokenizer, type_path="train", args=self.hparams)
        dataloader = DataLoader(train_dataset, batch_size=self.hparams.train_batch_size, drop_last=True, shuffle=True,
                                num_workers=4)
        t_total = (
                (len(dataloader.dataset) // (self.hparams.train_batch_size * max(1, self.hparams.n_gpu)))
                // self.hparams.gradient_accumulation_steps
                * float(self.hparams.num_train_epochs)
        )
        scheduler = get_linear_schedule_with_warmup(
            self.opt, num_warmup_steps=self.hparams.warmup_steps, num_training_steps=t_total
        )
        self.lr_scheduler = scheduler
        return dataloader

    def val_dataloader(self):
        print('loading val data')
        val_dataset = get_dataset(tokenizer=self.tokenizer, type_path="val", args=self.hparams)
        return DataLoader(val_dataset, batch_size=self.hparams.eval_batch_size, num_workers=4)


if __name__ == '__main__':
    set_seed(42)

    args_dict = dict(
        data_dir="",  # path for data files
        output_dir="",  # path to save the checkpoints
        model_name_or_path='t5-base',
        tokenizer_name_or_path='t5-base',
        max_seq_length=512,
        learning_rate=3e-4,
        weight_decay=0.0,
        adam_epsilon=1e-8,
        warmup_steps=0,
        train_batch_size=8,
        eval_batch_size=8,
        num_train_epochs=2,
        gradient_accumulation_steps=16,
        n_gpu=1,
        early_stop_callback=False,
        fp_16=False,  # if you want to enable 16-bit training then install apex and set this to true
        opt_level='O1',
        max_grad_norm=1.0,  # if you enable 16-bit training then set this to a sensible value, 0.5 is a good default
        seed=42,
    )

    # Prepare tokenizer
    tokenizer = T5Tokenizer.from_pretrained('t5-base')

    ids_neg = tokenizer.encode('inconsistent </s>')
    ids_pos = tokenizer.encode('consistent </s>')
    len(ids_neg), len(ids_pos)

    # Prepare dataset
    dataset = GraphQlDataset(tokenizer, 'graphql_dataset', 'val', max_len=512)
    len(dataset)

    data = dataset[28]
    print(tokenizer.decode(data['source_ids']))
    print(tokenizer.decode(data['target_ids']))

    # Continue with model
    args_dict.update({'data_dir': 'graphql_dataset', 'output_dir': 't5_graphql_consistency', 'num_train_epochs': 2})
    args = argparse.Namespace(**args_dict)

    checkpoint_callback = pl.callbacks.ModelCheckpoint(
        dirpath=args.output_dir, filename="checkpoint", monitor="val_loss", mode="min", save_top_k=5
    )

    train_params = dict(
        accumulate_grad_batches=args.gradient_accumulation_steps,
        accelerator='gpu',
        max_epochs=args.num_train_epochs,
        precision=16 if args.fp_16 else 32,
        gradient_clip_val=args.max_grad_norm,
        callbacks=[LoggingCallback(), checkpoint_callback],
    )

    model = T5FineTuner(args)
    # Temporary for more speed:
    train_params["precision"] = '16-mixed'

    trainer = pl.Trainer(**train_params)
    trainer.fit(model)

    ## save the model this way so next time you can load it using T5ForConditionalGeneration.from_pretrained
    model.model.save_pretrained('t5_base_graphql_consistency')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:163: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:226: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
#   0%|          | 0/2753 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2377: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 100%|██████████| 2753/2753 [00:02<00:00, 1151.14it/s]
# 100%|██████████| 2753/2753 [00:02<00:00, 1181.13it/s]
# <unk> result importBankTransactionsdata $data <unk> bankAccount $<unk> BANK_ACCOUNT_FIELDS<unk> <unk> <unk> <unk> s>importBankTransactions $data ImportBankTransactionsInput</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# consistent</s>
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 222 M
# -----------------------------------------------------
# 222 M     Trainable params
# 0         Non-trainable params
# 222 M     Total params
# 891.614   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# loading val data
#   0%|          | 0/2753 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2377: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:226: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
#
#   5%|▍         | 137/2753 [00:00<00:01, 1364.93it/s]
#  10%|▉         | 274/2753 [00:00<00:02, 1185.41it/s]
#  14%|█▍        | 395/2753 [00:00<00:02, 1098.78it/s]
#  18%|█▊        | 506/2753 [00:00<00:02, 1059.08it/s]
#  22%|██▏       | 613/2753 [00:00<00:02, 1045.92it/s]
#  27%|██▋       | 740/2753 [00:00<00:01, 1114.92it/s]
#  31%|███▏      | 863/2753 [00:00<00:01, 1149.72it/s]
#  36%|███▌      | 989/2753 [00:00<00:01, 1181.39it/s]
#  41%|████      | 1122/2753 [00:00<00:01, 1225.21it/s]
#  46%|████▌     | 1255/2753 [00:01<00:01, 1254.76it/s]
#  50%|█████     | 1381/2753 [00:01<00:01, 1232.24it/s]
#  55%|█████▍    | 1508/2753 [00:01<00:01, 1239.98it/s]
#  59%|█████▉    | 1633/2753 [00:01<00:00, 1183.77it/s]
#  64%|██████▎   | 1753/2753 [00:01<00:00, 1141.33it/s]
#  68%|██████▊   | 1868/2753 [00:01<00:00, 1106.60it/s]
#  72%|███████▏  | 1980/2753 [00:01<00:00, 1086.23it/s]
#  76%|███████▌  | 2095/2753 [00:01<00:00, 1104.00it/s]
#  81%|████████  | 2219/2753 [00:01<00:00, 1141.77it/s]
#  86%|████████▌ | 2360/2753 [00:02<00:00, 1219.17it/s]
#  91%|█████████ | 2495/2753 [00:02<00:00, 1257.34it/s]
# 100%|██████████| 2753/2753 [00:02<00:00, 1175.60it/s]
#
#   0%|          | 0/2753 [00:00<?, ?it/s]
#   4%|▍         | 117/2753 [00:00<00:02, 1166.62it/s]
#   9%|▊         | 235/2753 [00:00<00:02, 1171.50it/s]
#  13%|█▎        | 361/2753 [00:00<00:01, 1209.41it/s]
#  18%|█▊        | 482/2753 [00:00<00:01, 1158.45it/s]
#  22%|██▏       | 602/2753 [00:00<00:01, 1172.74it/s]
#  26%|██▌       | 720/2753 [00:00<00:01, 1147.51it/s]
#  31%|███       | 843/2753 [00:00<00:01, 1173.24it/s]
#  35%|███▌      | 969/2753 [00:00<00:01, 1198.35it/s]
#  40%|███▉      | 1093/2753 [00:00<00:01, 1209.03it/s]
#  44%|████▍     | 1215/2753 [00:01<00:01, 1205.92it/s]
#  49%|████▊     | 1336/2753 [00:01<00:01, 1174.66it/s]
#  53%|█████▎    | 1454/2753 [00:01<00:01, 1156.90it/s]
#  57%|█████▋    | 1570/2753 [00:01<00:01, 1082.23it/s]
#  61%|██████    | 1685/2753 [00:01<00:00, 1100.81it/s]
#  65%|██████▌   | 1796/2753 [00:01<00:00, 1096.85it/s]
#  69%|██████▉   | 1907/2753 [00:01<00:00, 1091.95it/s]
#  73%|███████▎  | 2017/2753 [00:01<00:00, 1092.10it/s]
#  77%|███████▋  | 2132/2753 [00:01<00:00, 1106.52it/s]
#  81%|████████▏ | 2243/2753 [00:02<00:00, 555.23it/s]
#  85%|████████▌ | 2342/2753 [00:02<00:00, 630.45it/s]
#  89%|████████▉ | 2449/2753 [00:02<00:00, 717.27it/s]
#  93%|█████████▎| 2557/2753 [00:02<00:00, 797.30it/s]
# 100%|██████████| 2753/2753 [00:02<00:00, 989.43it/s]
# loadingtrain data
# 100%|██████████| 2753/2753 [00:02<00:00, 1220.03it/s]
# 100%|██████████| 2753/2753 [00:02<00:00, 1195.76it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=2` reached.

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

# %%
dataset = GraphQlDataset(tokenizer, 'graphql_dataset', 'val',  max_len=512)
loader = DataLoader(dataset, batch_size=32, shuffle=True)
# Out:
#   0%|          | 0/2753 [00:00<?, ?it/s]
#   0%|          | 0/2753 [00:00<?, ?it/s]

# %%
it = iter(loader)
batch = next(it)
batch["source_ids"].shape
model.model.to('cuda')
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=32128, bias=False)
# )

# %%
outs = model.model.generate(input_ids=batch['source_ids'].cuda(),
                              attention_mask=batch['source_mask'].cuda(),
                              max_length=2)

dec = [tokenizer.decode(ids) for ids in outs]

texts = [tokenizer.decode(ids) for ids in batch['source_ids']]
targets = [tokenizer.decode(ids) for ids in batch['target_ids']]

# %%
for i in range(32):
    lines = textwrap.wrap("GraphQl Entry:\n%s\n" % texts[i], width=100)
    print("\n".join(lines))
    print("\nActual consistency: %s" % targets[i])
    print("Predicted consistency: %s" % dec[i])
    print("=====================================================================\n")
# Out:
# GraphQl Entry: <unk> meeting_LinkAttachmentmeetingId $meetingId attachmentId $attachmentId <unk> id
# includes <unk> id name mimeType <unk> <unk> <unk> <unk> s>meetingLinkAttachment$meetingId ID
# $attachmentId ID</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> newNotice <unk> NOTICE_ATTRIBUTES <unk> <unk> $<unk> NOTICE_ATTRIBUTES<unk>
# <unk> s>newNotice</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> message createMessagemessage $message <unk> id chatId user <unk> username
# userId first_name last_name username language payload createdAt email <unk> <unk> <unk> <unk>
# s>$message InputMessage</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> molochesorderBy summoningTime first 100 skip $skip <unk> id title version
# totalShares guildBankAddress summoningTime guildBankBalanceV1 guildBankValue @client apiData @client
# memberswhere <unk> exists true <unk> <unk> id <unk> proposals <unk> id <unk> approvedTokens <unk> id
# <unk> depositToken <unk> tokenAddress symbol decimals <unk> tokenBalanceswhere <unk> guildBank true
# <unk> <unk> id tokenBalance guildBank token <unk> decimals tokenAddress <unk> <unk> <unk> <unk>
# <unk> s>moloches$skip Int</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> servicename $name namespace $namespace <unk> name json labels clusterIP UID
# <unk> <unk> <unk> s>createNamespace$name String $labels Labels</s><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad>
#
# Actual consistency: inconsistent</s>
# Predicted consistency: <pad>inconsistent
# =====================================================================
#
# GraphQl Entry: <unk> onDeleteMember <unk> id name createdAt updatedAt <unk> <unk> <unk> s>Config</s>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad>
#
# Actual consistency: inconsistent</s>
# Predicted consistency: <pad>inconsistent
# =====================================================================
#
# GraphQl Entry: <unk> movie name $name <unk> releaseDate <unk> <unk> <unk> s>$name String</s><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> stampCmsPassportuserId $userId rules $rules <unk> id <unk> <unk> <unk>
# s>$userId ID $rules String</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> voterepoFullName $repoFullName type $type <unk> score id vote <unk> vote_value
# <unk> <unk> <unk> <unk> s>getUsers</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: inconsistent</s>
# Predicted consistency: <pad>inconsistent
# =====================================================================
#
# GraphQl Entry: <unk> sendFromWalletfrom $from to $to value $value <unk> id <unk> <unk> <unk>
# s>deletePost$post String</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad>
#
# Actual consistency: inconsistent</s>
# Predicted consistency: <pad>inconsistent
# =====================================================================
#
# GraphQl Entry: <unk> createNote1input $input <unk> noteId noteType owner <unk> <unk> <unk>
# s>CreateNote1$input CreateNote1Input</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> getDashboarddashboardUri $dashboardUri <unk> dashboardUri name owner
# SamlGroupName description label created tags userRoleForDashboard DashboardId upvotes environment
# <unk> label region <unk> organization <unk> organizationUri label name <unk> terms <unk> count nodes
# <unk> nodeUri path label <unk> <unk> <unk> <unk> <unk> s>GetDashboard$dashboardUri String</s><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> updateEnvironmentStackenvironmentUri $environmentUri <unk> <unk>
# s>updateMember$profile ProfileUpdateInput</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad>
#
# Actual consistency: inconsistent</s>
# Predicted consistency: <pad>inconsistent
# =====================================================================
#
# GraphQl Entry: <unk> updateFunctionname $name namespace $namespace params $params <unk> name <unk>
# <unk> <unk> s>updateFunction $name String $namespace String $params FunctionMutationInput</s><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> celoSystemHistory <unk> BlockNumber SnapshotDate GoldTokenSupply
# TotalLockedGoldBalance NonVotingLockedGoldBalance TotalCeloUSDValue <unk> <unk> <unk>
# s>DeployIdentity $from String $profile ProfileInput $attestations String</s><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: inconsistent</s>
# Predicted consistency: <pad>inconsistent
# =====================================================================
#
# GraphQl Entry: <unk> deleteCategoryid $id <unk> id <unk> <unk> <unk> s>$id Int</s><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> deleteServiceBinding serviceBindingName $serviceBindingName namespace
# $namespace <unk> name <unk> <unk> <unk> s>TransactionReceipt$id ID</s><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# <pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: inconsistent</s>
# Predicted consistency: <pad>inconsistent
# =====================================================================
#
# GraphQl Entry: <unk> createTasklistId $listId tasks $tasks <unk> errors <unk> path message <unk>
# success <unk> <unk> <unk> s>GetStorageSettings$appId uuid</s><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad
# ><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: inconsistent</s>
# Predicted consistency: <pad>inconsistent
# =====================================================================
#
# GraphQl Entry: <unk> updateTokenAllowancetoken $token from $from to $to value $value <unk> id <unk>
# <unk> <unk> s>Tips</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# ...
# =====================================================================
#
# GraphQl Entry: <unk> signMessageaddress $address message $message <unk> <unk>
# s>TreasuryProposalPostAndComments$id Int</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><
# pad><pad>
#
# Actual consistency: inconsistent</s>
# Predicted consistency: <pad>inconsistent
# =====================================================================
#
# GraphQl Entry: <unk> fileswhere $where limit $limit offset $offset order_by $order_by <unk> id
# bucketId createdAt updatedAt name size mimeType etag isUploaded uploadedByUserId <unk> <unk> <unk>
# s>functions$namespace String</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: inconsistent</s>
# Predicted consistency: <pad>inconsistent
# =====================================================================
#
# GraphQl Entry: <unk> Follow_aggregatewhere <unk> following_id <unk> _eq $id <unk> <unk> <unk>
# aggregate <unk> count <unk> <unk> <unk> <unk> s>$id String</s><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pa
# d><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> meme_templates <unk> id title image_link <unk> <unk> <unk> s>GetTemplates</s><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> getOrganizationorganizationUri $organizationUri <unk> organizationUri label
# tags SamlGroupName owner created description userRoleInOrganization stats <unk> environments groups
# <unk> <unk> <unk> <unk> s>GetOrganization$organizationUri String</s><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
#
# GraphQl Entry: <unk> replyCommentthread $thread id $id body $body <unk> id body <unk> <unk> <unk>
# s>$thread CmsThread $id ID $body String</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><p
# ad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Actual consistency: consistent</s>
# Predicted consistency: <pad>consistent
# =====================================================================
